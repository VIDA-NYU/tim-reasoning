# %% [markdown]
# # Generating Synthetic Data

# %%
import pandas as pd
from os.path import join

# %%
DATA_FOLDER = 'resource/perception_object_states'
OBJECTS = {'pinwheels': ['tortilla', 'plate', 'knife'], 'oatmeal': ['bowl']}

# %%
raw_annotations_path = join(DATA_FOLDER, 'raw_annotations.csv')
annotations = pd.read_csv(raw_annotations_path)
annotations.head(10)
# Out:
#       recipe                     video_name  time            step bowl  \
# 0  pinwheels  pinwheels_2023.03.01-21.35.14  0:00  place tortilla  NaN
# 1  pinwheels  pinwheels_2023.03.01-21.35.14  0:15             NaN  NaN
# 2  pinwheels  pinwheels_2023.03.01-21.35.14  0:52       spread PB  NaN
# 3  pinwheels  pinwheels_2023.03.01-21.35.14  1:07             NaN  NaN
# 4  pinwheels  pinwheels_2023.03.01-21.35.14  1:27             NaN  NaN
# 5  pinwheels  pinwheels_2023.03.01-21.35.14  1:42     clean knife  NaN
# 6  pinwheels  pinwheels_2023.03.01-21.35.14  3:43        spread J  NaN
# 7  pinwheels  pinwheels_2023.03.01-21.35.14   NaN             NaN  NaN
# 8  pinwheels  pinwheels_2023.03.01-21.35.14   NaN             NaN  NaN
# 9  pinwheels  pinwheels_2023.03.01-21.35.14  4:13     clean knife  NaN
#
#    microwave                tortilla  plate knife Object exhaustive
# 0        NaN              in-package  empty   NaN               NaN
# 1        NaN                   plain    NaN   NaN               NaN
# 2        NaN                     NaN    NaN   NaN               NaN
# 3        NaN  peanut-butter[partial]    NaN   NaN               NaN
# 4        NaN     peanut-butter[full]    NaN   NaN               NaN
# 5        NaN                     NaN    NaN   NaN               NaN
# 6        NaN                     NaN    NaN   NaN               NaN
# 7        NaN       pb+jelly[partial]    NaN   NaN               NaN
# 8        NaN          pb+jelly[full]    NaN   NaN               NaN
# 9        NaN                     NaN    NaN   NaN               NaN

# %% [markdown]
# ### Cleaning Annotated Data

# %%
import copy

def to_seconds(minutes_seconds):
    minutes, seconds =  map(int, minutes_seconds.split(':'))
    only_seconds = minutes * 60 + seconds
    
    return only_seconds

def format_annotations(annotations, video_id):
    video_annotations = copy.deepcopy(annotations[annotations['video_name'] == video_id])
    video_annotations = video_annotations[pd.notnull(video_annotations['time'])]
    video_annotations['start_time'] = video_annotations['time'].apply(to_seconds)
    video_annotations['end_time'] = video_annotations['start_time'].shift(-1).astype('Int64', errors='ignore').sub(1)
    recipe_id = video_annotations.iloc[0]['recipe']  
    step_id = 0
    tracked_objects = OBJECTS[recipe_id]
    current_states = {o: None for o in tracked_objects}
    formatted_annotations = {'recipe': [], 'video': [], 'start_time': [], 'end_time': [], 'step': []}
    formatted_annotations.update({o: [] for o in tracked_objects})
    
    for _, row in video_annotations.iterrows():
        current_step = row['step']
        if not pd.isna(current_step):
            step_id += 1
        
        for tracked_object in tracked_objects:
            current_state = row[tracked_object]
            if not pd.isna(current_state):
                current_states[tracked_object] = current_state
            formatted_annotations[tracked_object].append(current_states[tracked_object])
        formatted_annotations['recipe'].append(row['recipe'])
        formatted_annotations['video'].append(row['video_name'])
        formatted_annotations['start_time'].append(row['start_time'])
        formatted_annotations['end_time'].append(row['end_time'])
        formatted_annotations['step'].append(step_id)
    
    formatted_annotations['end_time'][-1] = formatted_annotations['start_time'][-1] + 3 # Last element doesn't have and end time, just add 3 secs
    formatted_annotations_df = pd.DataFrame.from_dict(formatted_annotations)
  
    return formatted_annotations_df

# %%
video_id = 'pinwheels_2023.04.04-18.33.59'
formatted_annotations_p = format_annotations(annotations, video_id)
formatted_annotations_p
# Out:
#        recipe                          video  start_time  end_time  step  \
# 0   pinwheels  pinwheels_2023.04.04-18.33.59           0         5     1
# 1   pinwheels  pinwheels_2023.04.04-18.33.59           6        17     1
# 2   pinwheels  pinwheels_2023.04.04-18.33.59          18        23     2
# 3   pinwheels  pinwheels_2023.04.04-18.33.59          24        26     2
# 4   pinwheels  pinwheels_2023.04.04-18.33.59          27        40     2
# 5   pinwheels  pinwheels_2023.04.04-18.33.59          41        49     2
# 6   pinwheels  pinwheels_2023.04.04-18.33.59          50        60     3
# 7   pinwheels  pinwheels_2023.04.04-18.33.59          61        64     3
# 8   pinwheels  pinwheels_2023.04.04-18.33.59          65        70     4
# 9   pinwheels  pinwheels_2023.04.04-18.33.59          71        72     4
# 10  pinwheels  pinwheels_2023.04.04-18.33.59          73        77     4
# 11  pinwheels  pinwheels_2023.04.04-18.33.59          78        90     4
# 12  pinwheels  pinwheels_2023.04.04-18.33.59          91        93     5
# 13  pinwheels  pinwheels_2023.04.04-18.33.59          94        99     5
# 14  pinwheels  pinwheels_2023.04.04-18.33.59         100       100     6
# 15  pinwheels  pinwheels_2023.04.04-18.33.59         101       105     6
# 16  pinwheels  pinwheels_2023.04.04-18.33.59         106       111     6
# 17  pinwheels  pinwheels_2023.04.04-18.33.59         112       119     7
# 18  pinwheels  pinwheels_2023.04.04-18.33.59         120       127     7
# 19  pinwheels  pinwheels_2023.04.04-18.33.59         128       134     7
# 20  pinwheels  pinwheels_2023.04.04-18.33.59         135       137     8
# 21  pinwheels  pinwheels_2023.04.04-18.33.59         138       144     8
# 22  pinwheels  pinwheels_2023.04.04-18.33.59         145       153     8
# 23  pinwheels  pinwheels_2023.04.04-18.33.59         154       168     9
# 24  pinwheels  pinwheels_2023.04.04-18.33.59         169       172     9
# 25  pinwheels  pinwheels_2023.04.04-18.33.59         173       172    10
# 26  pinwheels  pinwheels_2023.04.04-18.33.59         173       180    10
# 27  pinwheels  pinwheels_2023.04.04-18.33.59         181       181    10
# 28  pinwheels  pinwheels_2023.04.04-18.33.59         182       232    11
# 29  pinwheels  pinwheels_2023.04.04-18.33.59         233       238    11
# 30  pinwheels  pinwheels_2023.04.04-18.33.59         239       239    12
# 31  pinwheels  pinwheels_2023.04.04-18.33.59         240       244    12
# 32  pinwheels  pinwheels_2023.04.04-18.33.59         245       248    12
#
#                       tortilla                    plate  knife
# 0                   in-package                    empty  clean
# 1                        plain                    empty  clean
# 2                        plain                    empty  clean
# 3                        plain                    empty  dirty
# 4       peanut-butter[partial]                    empty  dirty
# 5          peanut-butter[full]                    empty  dirty
# 6          peanut-butter[full]                    empty  dirty
# 7          peanut-butter[full]                    empty  clean
# 8          peanut-butter[full]                    empty  clean
# 9          peanut-butter[full]                    empty  dirty
# 10           pb+jelly[partial]                    empty  dirty
# 11              pb+jelly[full]                    empty  dirty
# 12              pb+jelly[full]                    empty  dirty
# 13              pb+jelly[full]                    empty  clean
# 14              pb+jelly[full]                    empty  clean
# 15                     rolling                    empty  clean
# 16                      rolled                    empty  clean
# 17                      rolled                    empty  clean
# 18  rolled+toothpicks[partial]                    empty  clean
# 19     rolled+toothpicks[full]                    empty  clean
# 20     rolled+toothpicks[full]                    empty  clean
# 21           ends-cut[partial]                    empty  clean
# 22              ends-cut[full]                    empty  clean
# 23              ends-cut[full]                    empty  clean
# 24            floss-underneath                    empty  clean
# 25            floss-underneath                    empty  clean
# 26               floss-crossed                    empty  clean
# 27             sliced[partial]                    empty  clean
# 28             sliced[partial]                    empty  clean
# 29                sliced[full]                    empty  clean
# 30                sliced[full]                    empty  clean
# 31           on-plate[partial]  with-pinwheels[partial]  clean
# 32              on-plate[full]     with-pinwheels[full]  clean

# %% [markdown]
# ### Generating Perception Outputs

# %%
import json
from datetime import datetime

CURRENT_TIME = int(datetime.now().timestamp())
PERCEPTION_OUTPUT_TEMPLATE = {
        "pos": [-0.2149151724097291, -0.4343880843796524, -0.6208099189217009],
        "xyxyn": [0.1, 0.1, 0.2, 0.2],
        "label": "",
        "status": "tracked",
        "id": "1",
        "last_seen":"",
        "state": {},
        "hand_object_interaction": 0.27,
    }
MAPPING_IDS = {'tortilla': 0, 'knife': 1, 'plate': 2, 'bowl':3}


def select_tracked_objects(row, objects):
    tracked_objects = {}
    
    for obj in objects:
        if row[obj] != '':
            tracked_objects[obj] = row[obj]
    
    return tracked_objects


def get_unique_states(annotations, objects):
    unique_states = {}
    
    for obj in objects:
        states = annotations[obj].unique()
        unique_states[obj] = list(states)
    
    return unique_states


def read_annotated_video(video_annotations):
    recipe_id = video_annotations.iloc[0]['recipe']
    unique_states = get_unique_states(video_annotations, OBJECTS[recipe_id])    
    annotated_video = {'task_id': recipe_id, 'session_id': video_id, 'records': {}, 'unique_states': unique_states}
    
    for _, row in video_annotations.iterrows():
        tracked_objects = select_tracked_objects(row, OBJECTS[recipe_id])
        step_id = row['step']
        if step_id not in annotated_video['records']:
            annotated_video['records'][step_id] = []
        annotated_video['records'][step_id].append({'start_time': row['start_time'], 'end_time': row['end_time'], 'objects': tracked_objects})
    
    return annotated_video


def make_perception_outputs(annotated_video):
    perception_outputs = []
        
    for step_id, step_annotations in annotated_video['records'].items():
        session_annotation = {'session_id': annotated_video['session_id'], 'task_id': annotated_video['task_id'], 'step_id': step_id}
        for step_annotation in step_annotations:
            step_outputs = make_step_outputs(session_annotation, step_annotation, annotated_video['unique_states'], PERCEPTION_OUTPUT_TEMPLATE)
            perception_outputs += step_outputs
    
    return perception_outputs


def make_step_outputs(session_annotation, step_annotation, unique_states, output_template, target_state_probas=None, target_object=None):
    objects = step_annotation['objects']
    start_time = step_annotation['start_time']
    end_time = step_annotation['end_time']
    step_outputs = []
    
    for time_secs in range(start_time, end_time+1):
        time_stamp = CURRENT_TIME + time_secs
        for object_name, object_state in objects.items():
            object_output = copy.deepcopy(output_template)
            object_output['id'] = MAPPING_IDS[object_name]
            object_output['session'] = session_annotation
            object_output['label'] = object_name
            object_output['last_seen'] = time_stamp
            state_probas = {s: 0.0 for s in unique_states[object_name]}
            state_probas[object_state] = 1.0
            object_output['state'] = state_probas
            
            if object_name == target_object:
                object_output['state'] = target_state_probas
                
            step_outputs.append(object_output)
            
    return step_outputs


def save_outputs(outputs, file_name):
    with open(join(DATA_FOLDER, f'{file_name}.json'), 'w') as fout:
        json.dump(outputs, fout, indent=2)
    print(json.dumps(outputs, indent=2))

# %%
pinwheels_annotations = read_annotated_video(formatted_annotations_p)
pinwheels_perception_outputs = make_perception_outputs(pinwheels_annotations)
save_outputs(pinwheels_perception_outputs, 'pinwheels_session')
# Out:
# [
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697591895,
#     "state": {
#       "in-package": 1.0,
#       "plain": 0.0,
#       "peanut-butter[partial]": 0.0,
#       "peanut-butter[full]": 0.0,
#       "pb+jelly[partial]": 0.0,
#       "pb+jelly[full]": 0.0,
#       "rolling": 0.0,
#       "rolled": 0.0,
#       "rolled+toothpicks[partial]": 0.0,
#       "rolled+toothpicks[full]": 0.0,
#       "ends-cut[partial]": 0.0,
#       "ends-cut[full]": 0.0,
#       "floss-underneath": 0.0,
#       "floss-crossed": 0.0,
#       "sliced[partial]": 0.0,
#       "sliced[full]": 0.0,
#       "on-plate[partial]": 0.0,
#       "on-plate[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697591895,
#     "state": {
#       "empty": 1.0,
#       "with-pinwheels[partial]": 0.0,
#       "with-pinwheels[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
#     "id": 1,
#     "last_seen": 1697591895,
#     "state": {
#       "clean": 1.0,
#       "dirty": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697591896,
#     "state": {
#       "in-package": 1.0,
#       "plain": 0.0,
#       "peanut-butter[partial]": 0.0,
#       "peanut-butter[full]": 0.0,
#       "pb+jelly[partial]": 0.0,
#       "pb+jelly[full]": 0.0,
#       "rolling": 0.0,
#       "rolled": 0.0,
#       "rolled+toothpicks[partial]": 0.0,
#       "rolled+toothpicks[full]": 0.0,
#       "ends-cut[partial]": 0.0,
#       "ends-cut[full]": 0.0,
#       "floss-underneath": 0.0,
#       "floss-crossed": 0.0,
#       "sliced[partial]": 0.0,
#       "sliced[full]": 0.0,
#       "on-plate[partial]": 0.0,
#       "on-plate[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697591896,
#     "state": {
#       "empty": 1.0,
#       "with-pinwheels[partial]": 0.0,
#       "with-pinwheels[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
#     "id": 1,
#     "last_seen": 1697591896,
#     "state": {
#       "clean": 1.0,
#       "dirty": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697591897,
#     "state": {
#       "in-package": 1.0,
#       "plain": 0.0,
#       "peanut-butter[partial]": 0.0,
#       "peanut-butter[full]": 0.0,
#       "pb+jelly[partial]": 0.0,
#       "pb+jelly[full]": 0.0,
#       "rolling": 0.0,
#       "rolled": 0.0,
#       "rolled+toothpicks[partial]": 0.0,
#       "rolled+toothpicks[full]": 0.0,
#       "ends-cut[partial]": 0.0,
#       "ends-cut[full]": 0.0,
#       "floss-underneath": 0.0,
#       "floss-crossed": 0.0,
#       "sliced[partial]": 0.0,
#       "sliced[full]": 0.0,
#       "on-plate[partial]": 0.0,
#       "on-plate[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697591897,
#     "state": {
#       "empty": 1.0,
#       "with-pinwheels[partial]": 0.0,
#       "with-pinwheels[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
#     "id": 1,
#     "last_seen": 1697591897,
#     "state": {
#       "clean": 1.0,
#       "dirty": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697591898,
#     "state": {
#       "in-package": 1.0,
#       "plain": 0.0,
#       "peanut-butter[partial]": 0.0,
#       "peanut-butter[full]": 0.0,
#       "pb+jelly[partial]": 0.0,
#       "pb+jelly[full]": 0.0,
#       "rolling": 0.0,
#       "rolled": 0.0,
#       "rolled+toothpicks[partial]": 0.0,
#       "rolled+toothpicks[full]": 0.0,
#       "ends-cut[partial]": 0.0,
#       "ends-cut[full]": 0.0,
#       "floss-underneath": 0.0,
#       "floss-crossed": 0.0,
#       "sliced[partial]": 0.0,
#       "sliced[full]": 0.0,
#       "on-plate[partial]": 0.0,
#       "on-plate[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697591898,
#     "state": {
#       "empty": 1.0,
#       "with-pinwheels[partial]": 0.0,
#       "with-pinwheels[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
#     "id": 1,
#     "last_seen": 1697591898,
#     "state": {
#       "clean": 1.0,
#       "dirty": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697591899,
#     "state": {
#       "in-package": 1.0,
#       "plain": 0.0,
#       "peanut-butter[partial]": 0.0,
#       "peanut-butter[full]": 0.0,
#       "pb+jelly[partial]": 0.0,
#       "pb+jelly[full]": 0.0,
#       "rolling": 0.0,
#       "rolled": 0.0,
#       "rolled+toothpicks[partial]": 0.0,
#       "rolled+toothpicks[full]": 0.0,
#       "ends-cut[partial]": 0.0,
#       "ends-cut[full]": 0.0,
#       "floss-underneath": 0.0,
#       "floss-crossed": 0.0,
#       "sliced[partial]": 0.0,
#       "sliced[full]": 0.0,
#       "on-plate[partial]": 0.0,
#       "on-plate[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697591899,
#     "state": {
#       "empty": 1.0,
#       "with-pinwheels[partial]": 0.0,
#       "with-pinwheels[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
#     "id": 1,
#     "last_seen": 1697591899,
#     "state": {
#       "clean": 1.0,
#       "dirty": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697591900,
#     "state": {
#       "in-package": 1.0,
#       "plain": 0.0,
#       "peanut-butter[partial]": 0.0,
#       "peanut-butter[full]": 0.0,
#       "pb+jelly[partial]": 0.0,
#       "pb+jelly[full]": 0.0,
#       "rolling": 0.0,
#       "rolled": 0.0,
#       "rolled+toothpicks[partial]": 0.0,
#       "rolled+toothpicks[full]": 0.0,
#       "ends-cut[partial]": 0.0,
#       "ends-cut[full]": 0.0,
#       "floss-underneath": 0.0,
#       "floss-crossed": 0.0,
#       "sliced[partial]": 0.0,
#       "sliced[full]": 0.0,
#       "on-plate[partial]": 0.0,
#       "on-plate[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697591900,
#     "state": {
#       "empty": 1.0,
#       "with-pinwheels[partial]": 0.0,
#       "with-pinwheels[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
#     "id": 1,
#     "last_seen": 1697591900,
#     "state": {
#       "clean": 1.0,
#       "dirty": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697591901,
#     "state": {
#       "in-package": 0.0,
#       "plain": 1.0,
#       "peanut-butter[partial]": 0.0,
#       "peanut-butter[full]": 0.0,
#       "pb+jelly[partial]": 0.0,
#       "pb+jelly[full]": 0.0,
#       "rolling": 0.0,
#       "rolled": 0.0,
#       "rolled+toothpicks[partial]": 0.0,
#       "rolled+toothpicks[full]": 0.0,
#       "ends-cut[partial]": 0.0,
#       "ends-cut[full]": 0.0,
#       "floss-underneath": 0.0,
#       "floss-crossed": 0.0,
#       "sliced[partial]": 0.0,
#       "sliced[full]": 0.0,
#       "on-plate[partial]": 0.0,
#       "on-plate[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697591901,
#     "state": {
#       "empty": 1.0,
#       "with-pinwheels[partial]": 0.0,
#       "with-pinwheels[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
#     "id": 1,
#     "last_seen": 1697591901,
#     "state": {
#       "clean": 1.0,
#       "dirty": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697591902,
#     "state": {
#       "in-package": 0.0,
#       "plain": 1.0,
#       "peanut-butter[partial]": 0.0,
#       "peanut-butter[full]": 0.0,
#       "pb+jelly[partial]": 0.0,
#       "pb+jelly[full]": 0.0,
#       "rolling": 0.0,
#       "rolled": 0.0,
#       "rolled+toothpicks[partial]": 0.0,
#       "rolled+toothpicks[full]": 0.0,
#       "ends-cut[partial]": 0.0,
#       "ends-cut[full]": 0.0,
#       "floss-underneath": 0.0,
#       "floss-crossed": 0.0,
#       "sliced[partial]": 0.0,
#       "sliced[full]": 0.0,
#       "on-plate[partial]": 0.0,
#       "on-plate[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697591902,
#     "state": {
#       "empty": 1.0,
#       "with-pinwheels[partial]": 0.0,
#       "with-pinwheels[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
#     "id": 1,
#     "last_seen": 1697591902,
#     "state": {
#       "clean": 1.0,
#       "dirty": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697591903,
#     "state": {
#       "in-package": 0.0,
#       "plain": 1.0,
#       "peanut-butter[partial]": 0.0,
#       "peanut-butter[full]": 0.0,
#       "pb+jelly[partial]": 0.0,
#       "pb+jelly[full]": 0.0,
#       "rolling": 0.0,
#       "rolled": 0.0,
#       "rolled+toothpicks[partial]": 0.0,
#       "rolled+toothpicks[full]": 0.0,
#       "ends-cut[partial]": 0.0,
#       "ends-cut[full]": 0.0,
#       "floss-underneath": 0.0,
#       "floss-crossed": 0.0,
#       "sliced[partial]": 0.0,
#       "sliced[full]": 0.0,
#       "on-plate[partial]": 0.0,
#       "on-plate[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697591903,
#     "state": {
#       "empty": 1.0,
#       "with-pinwheels[partial]": 0.0,
#       "with-pinwheels[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
#     "id": 1,
#     "last_seen": 1697591903,
#     "state": {
#       "clean": 1.0,
#       "dirty": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697591904,
#     "state": {
#       "in-package": 0.0,
#       "plain": 1.0,
#       "peanut-butter[partial]": 0.0,
#       "peanut-butter[full]": 0.0,
#       "pb+jelly[partial]": 0.0,
#       "pb+jelly[full]": 0.0,
#       "rolling": 0.0,
#       "rolled": 0.0,
#       "rolled+toothpicks[partial]": 0.0,
#       "rolled+toothpicks[full]": 0.0,
#       "ends-cut[partial]": 0.0,
#       "ends-cut[full]": 0.0,
#       "floss-underneath": 0.0,
#       "floss-crossed": 0.0,
#       "sliced[partial]": 0.0,
#       "sliced[full]": 0.0,
#       "on-plate[partial]": 0.0,
#       "on-plate[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697591904,
#     "state": {
#       "empty": 1.0,
#       "with-pinwheels[partial]": 0.0,
#       "with-pinwheels[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
#     "id": 1,
#     "last_seen": 1697591904,
#     "state": {
#       "clean": 1.0,
#       "dirty": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697591905,
#     "state": {
#       "in-package": 0.0,
#       "plain": 1.0,
#       "peanut-butter[partial]": 0.0,
#       "peanut-butter[full]": 0.0,
#       "pb+jelly[partial]": 0.0,
#       "pb+jelly[full]": 0.0,
#       "rolling": 0.0,
#       "rolled": 0.0,
#       "rolled+toothpicks[partial]": 0.0,
#       "rolled+toothpicks[full]": 0.0,
#       "ends-cut[partial]": 0.0,
#       "ends-cut[full]": 0.0,
#       "floss-underneath": 0.0,
#       "floss-crossed": 0.0,
#       "sliced[partial]": 0.0,
#       "sliced[full]": 0.0,
#       "on-plate[partial]": 0.0,
#       "on-plate[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697591905,
#     "state": {
#       "empty": 1.0,
#       "with-pinwheels[partial]": 0.0,
#       "with-pinwheels[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
#     "id": 1,
#     "last_seen": 1697591905,
#     "state": {
#       "clean": 1.0,
#       "dirty": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697591906,
#     "state": {
#       "in-package": 0.0,
#       "plain": 1.0,
#       "peanut-butter[partial]": 0.0,
#       "peanut-butter[full]": 0.0,
#       "pb+jelly[partial]": 0.0,
#       "pb+jelly[full]": 0.0,
#       "rolling": 0.0,
#       "rolled": 0.0,
#       "rolled+toothpicks[partial]": 0.0,
#       "rolled+toothpicks[full]": 0.0,
#       "ends-cut[partial]": 0.0,
#       "ends-cut[full]": 0.0,
#       "floss-underneath": 0.0,
#       "floss-crossed": 0.0,
#       "sliced[partial]": 0.0,
#       "sliced[full]": 0.0,
#       "on-plate[partial]": 0.0,
#       "on-plate[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697591906,
#     "state": {
#       "empty": 1.0,
#       "with-pinwheels[partial]": 0.0,
#       "with-pinwheels[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
#     "id": 1,
#     "last_seen": 1697591906,
#     "state": {
#       "clean": 1.0,
#       "dirty": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697591907,
#     "state": {
#       "in-package": 0.0,
#       "plain": 1.0,
#       "peanut-butter[partial]": 0.0,
#       "peanut-butter[full]": 0.0,
#       "pb+jelly[partial]": 0.0,
#       "pb+jelly[full]": 0.0,
#       "rolling": 0.0,
#       "rolled": 0.0,
#       "rolled+toothpicks[partial]": 0.0,
#       "rolled+toothpicks[full]": 0.0,
#       "ends-cut[partial]": 0.0,
#       "ends-cut[full]": 0.0,
#       "floss-underneath": 0.0,
#       "floss-crossed": 0.0,
#       "sliced[partial]": 0.0,
#       "sliced[full]": 0.0,
#       "on-plate[partial]": 0.0,
#       "on-plate[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697591907,
#     "state": {
#       "empty": 1.0,
#       "with-pinwheels[partial]": 0.0,
#       "with-pinwheels[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
#     "id": 1,
#     "last_seen": 1697591907,
#     "state": {
#       "clean": 1.0,
#       "dirty": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697591908,
#     "state": {
#       "in-package": 0.0,
#       "plain": 1.0,
#       "peanut-butter[partial]": 0.0,
#       "peanut-butter[full]": 0.0,
#       "pb+jelly[partial]": 0.0,
#       "pb+jelly[full]": 0.0,
#       "rolling": 0.0,
#       "rolled": 0.0,
#       "rolled+toothpicks[partial]": 0.0,
#       "rolled+toothpicks[full]": 0.0,
#       "ends-cut[partial]": 0.0,
#       "ends-cut[full]": 0.0,
#       "floss-underneath": 0.0,
#       "floss-crossed": 0.0,
#       "sliced[partial]": 0.0,
#       "sliced[full]": 0.0,
#       "on-plate[partial]": 0.0,
#       "on-plate[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697591908,
#     "state": {
#       "empty": 1.0,
#       "with-pinwheels[partial]": 0.0,
#       "with-pinwheels[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
#     "id": 1,
#     "last_seen": 1697591908,
#     "state": {
#       "clean": 1.0,
#       "dirty": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697591909,
#     "state": {
#       "in-package": 0.0,
#       "plain": 1.0,
#       "peanut-butter[partial]": 0.0,
#       "peanut-butter[full]": 0.0,
#       "pb+jelly[partial]": 0.0,
#       "pb+jelly[full]": 0.0,
#       "rolling": 0.0,
#       "rolled": 0.0,
#       "rolled+toothpicks[partial]": 0.0,
#       "rolled+toothpicks[full]": 0.0,
#       "ends-cut[partial]": 0.0,
#       "ends-cut[full]": 0.0,
#       "floss-underneath": 0.0,
#       "floss-crossed": 0.0,
#       "sliced[partial]": 0.0,
#       "sliced[full]": 0.0,
#       "on-plate[partial]": 0.0,
#       "on-plate[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697591909,
#     "state": {
#       "empty": 1.0,
#       "with-pinwheels[partial]": 0.0,
#       "with-pinwheels[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
#     "id": 1,
#     "last_seen": 1697591909,
#     "state": {
#       "clean": 1.0,
#       "dirty": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697591910,
#     "state": {
#       "in-package": 0.0,
#       "plain": 1.0,
#       "peanut-butter[partial]": 0.0,
#       "peanut-butter[full]": 0.0,
#       "pb+jelly[partial]": 0.0,
#       "pb+jelly[full]": 0.0,
#       "rolling": 0.0,
#       "rolled": 0.0,
#       "rolled+toothpicks[partial]": 0.0,
#       "rolled+toothpicks[full]": 0.0,
#       "ends-cut[partial]": 0.0,
#       "ends-cut[full]": 0.0,
#       "floss-underneath": 0.0,
#       "floss-crossed": 0.0,
#       "sliced[partial]": 0.0,
#       "sliced[full]": 0.0,
#       "on-plate[partial]": 0.0,
#       "on-plate[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697591910,
#     "state": {
#       "empty": 1.0,
#       "with-pinwheels[partial]": 0.0,
#       "with-pinwheels[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
#     "id": 1,
#     "last_seen": 1697591910,
#     "state": {
#       "clean": 1.0,
#       "dirty": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697591911,
#     "state": {
#       "in-package": 0.0,
#       "plain": 1.0,
#       "peanut-butter[partial]": 0.0,
#       "peanut-butter[full]": 0.0,
#       "pb+jelly[partial]": 0.0,
#       "pb+jelly[full]": 0.0,
#       "rolling": 0.0,
#       "rolled": 0.0,
#       "rolled+toothpicks[partial]": 0.0,
#       "rolled+toothpicks[full]": 0.0,
#       "ends-cut[partial]": 0.0,
#       "ends-cut[full]": 0.0,
#       "floss-underneath": 0.0,
#       "floss-crossed": 0.0,
#       "sliced[partial]": 0.0,
#       "sliced[full]": 0.0,
#       "on-plate[partial]": 0.0,
#       "on-plate[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697591911,
#     "state": {
#       "empty": 1.0,
#       "with-pinwheels[partial]": 0.0,
#       "with-pinwheels[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
#     "id": 1,
#     "last_seen": 1697591911,
#     "state": {
#       "clean": 1.0,
#       "dirty": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697591912,
#     "state": {
#       "in-package": 0.0,
#       "plain": 1.0,
#       "peanut-butter[partial]": 0.0,
#       "peanut-butter[full]": 0.0,
#       "pb+jelly[partial]": 0.0,
#       "pb+jelly[full]": 0.0,
#       "rolling": 0.0,
#       "rolled": 0.0,
#       "rolled+toothpicks[partial]": 0.0,
#       "rolled+toothpicks[full]": 0.0,
#       "ends-cut[partial]": 0.0,
#       "ends-cut[full]": 0.0,
#       "floss-underneath": 0.0,
#       "floss-crossed": 0.0,
#       "sliced[partial]": 0.0,
#       "sliced[full]": 0.0,
#       "on-plate[partial]": 0.0,
#       "on-plate[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697591912,
#     "state": {
#       "empty": 1.0,
#       "with-pinwheels[partial]": 0.0,
#       "with-pinwheels[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
#     "id": 1,
#     "last_seen": 1697591912,
#     "state": {
#       "clean": 1.0,
#       "dirty": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697591913,
#     "state": {
#       "in-package": 0.0,
#       "plain": 1.0,
#       "peanut-butter[partial]": 0.0,
#       "peanut-butter[full]": 0.0,
#       "pb+jelly[partial]": 0.0,
#       "pb+jelly[full]": 0.0,
#       "rolling": 0.0,
#       "rolled": 0.0,
#       "rolled+toothpicks[partial]": 0.0,
#       "rolled+toothpicks[full]": 0.0,
#       "ends-cut[partial]": 0.0,
#       "ends-cut[full]": 0.0,
#       "floss-underneath": 0.0,
#       "floss-crossed": 0.0,
#       "sliced[partial]": 0.0,
#       "sliced[full]": 0.0,
#       "on-plate[partial]": 0.0,
#       "on-plate[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 2
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697591913,
#     "state": {
#       "empty": 1.0,
#       "with-pinwheels[partial]": 0.0,
#       "with-pinwheels[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 2
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
#     "id": 1,
#     "last_seen": 1697591913,
#     "state": {
#       "clean": 1.0,
#       "dirty": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 2
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697591914,
#     "state": {
#       "in-package": 0.0,
#       "plain": 1.0,
#       "peanut-butter[partial]": 0.0,
#       "peanut-butter[full]": 0.0,
#       "pb+jelly[partial]": 0.0,
#       "pb+jelly[full]": 0.0,
#       "rolling": 0.0,
#       "rolled": 0.0,
#       "rolled+toothpicks[partial]": 0.0,
#       "rolled+toothpicks[full]": 0.0,
#       "ends-cut[partial]": 0.0,
#       "ends-cut[full]": 0.0,
#       "floss-underneath": 0.0,
#       "floss-crossed": 0.0,
#       "sliced[partial]": 0.0,
#       "sliced[full]": 0.0,
#       "on-plate[partial]": 0.0,
#       "on-plate[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 2
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697591914,
#     "state": {
#       "empty": 1.0,
#       "with-pinwheels[partial]": 0.0,
#       "with-pinwheels[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 2
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
#     "id": 1,
#     "last_seen": 1697591914,
#     "state": {
#       "clean": 1.0,
#       "dirty": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 2
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697591915,
#     "state": {
#       "in-package": 0.0,
#       "plain": 1.0,
#       "peanut-butter[partial]": 0.0,
#       "peanut-butter[full]": 0.0,
#       "pb+jelly[partial]": 0.0,
#       "pb+jelly[full]": 0.0,
#       "rolling": 0.0,
#       "rolled": 0.0,
#       "rolled+toothpicks[partial]": 0.0,
#       "rolled+toothpicks[full]": 0.0,
#       "ends-cut[partial]": 0.0,
#       "ends-cut[full]": 0.0,
#       "floss-underneath": 0.0,
#       "floss-crossed": 0.0,
#       "sliced[partial]": 0.0,
#       "sliced[full]": 0.0,
#       "on-plate[partial]": 0.0,
#       "on-plate[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 2
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697591915,
#     "state": {
#       "empty": 1.0,
#       "with-pinwheels[partial]": 0.0,
#       "with-pinwheels[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 2
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
#     "id": 1,
#     "last_seen": 1697591915,
#     "state": {
#       "clean": 1.0,
#       "dirty": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 2
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697591916,
#     "state": {
#       "in-package": 0.0,
#       "plain": 1.0,
#       "peanut-butter[partial]": 0.0,
#       "peanut-butter[full]": 0.0,
#       "pb+jelly[partial]": 0.0,
#       "pb+jelly[full]": 0.0,
#       "rolling": 0.0,
#       "rolled": 0.0,
#       "rolled+toothpicks[partial]": 0.0,
#       "rolled+toothpicks[full]": 0.0,
#       "ends-cut[partial]": 0.0,
#       "ends-cut[full]": 0.0,
#       "floss-underneath": 0.0,
#       "floss-crossed": 0.0,
#       "sliced[partial]": 0.0,
#       "sliced[full]": 0.0,
#       "on-plate[partial]": 0.0,
#       "on-plate[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 2
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697591916,
#     "state": {
#       "empty": 1.0,
#       "with-pinwheels[partial]": 0.0,
#       "with-pinwheels[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 2
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
#     "id": 1,
#     "last_seen": 1697591916,
#     "state": {
#       "clean": 1.0,
#       "dirty": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 2
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697591917,
#     "state": {
#       "in-package": 0.0,
#       "plain": 1.0,
#       "peanut-butter[partial]": 0.0,
#       "peanut-butter[full]": 0.0,
#       "pb+jelly[partial]": 0.0,
#       "pb+jelly[full]": 0.0,
#       "rolling": 0.0,
#       "rolled": 0.0,
#       "rolled+toothpicks[partial]": 0.0,
#       "rolled+toothpicks[full]": 0.0,
#       "ends-cut[partial]": 0.0,
#       "ends-cut[full]": 0.0,
#       "floss-underneath": 0.0,
#       "floss-crossed": 0.0,
#       "sliced[partial]": 0.0,
#       "sliced[full]": 0.0,
#       "on-plate[partial]": 0.0,
#       "on-plate[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 2
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697591917,
#     "state": {
#       "empty": 1.0,
#       "with-pinwheels[partial]": 0.0,
#       "with-pinwheels[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 2
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
#     "id": 1,
#     "last_seen": 1697591917,
#     "state": {
#       "clean": 1.0,
#       "dirty": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 2
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697591918,
#     "state": {
#       "in-package": 0.0,
#       "plain": 1.0,
#       "peanut-butter[partial]": 0.0,
#       "peanut-butter[full]": 0.0,
#       "pb+jelly[partial]": 0.0,
#       "pb+jelly[full]": 0.0,
#       "rolling": 0.0,
#       "rolled": 0.0,
#       "rolled+toothpicks[partial]": 0.0,
#       "rolled+toothpicks[full]": 0.0,
#       "ends-cut[partial]": 0.0,
#       "ends-cut[full]": 0.0,
#       "floss-underneath": 0.0,
#       "floss-crossed": 0.0,
#       "sliced[partial]": 0.0,
#       "sliced[full]": 0.0,
#       "on-plate[partial]": 0.0,
#       "on-plate[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 2
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697591918,
#     "state": {
#       "empty": 1.0,
#       "with-pinwheels[partial]": 0.0,
#       "with-pinwheels[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 2
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
# ...
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697592136,
#     "state": {
#       "in-package": 0.0,
#       "plain": 0.0,
#       "peanut-butter[partial]": 0.0,
#       "peanut-butter[full]": 0.0,
#       "pb+jelly[partial]": 0.0,
#       "pb+jelly[full]": 0.0,
#       "rolling": 0.0,
#       "rolled": 0.0,
#       "rolled+toothpicks[partial]": 0.0,
#       "rolled+toothpicks[full]": 0.0,
#       "ends-cut[partial]": 0.0,
#       "ends-cut[full]": 0.0,
#       "floss-underneath": 0.0,
#       "floss-crossed": 0.0,
#       "sliced[partial]": 0.0,
#       "sliced[full]": 0.0,
#       "on-plate[partial]": 1.0,
#       "on-plate[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 12
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697592136,
#     "state": {
#       "empty": 0.0,
#       "with-pinwheels[partial]": 1.0,
#       "with-pinwheels[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 12
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
#     "id": 1,
#     "last_seen": 1697592136,
#     "state": {
#       "clean": 1.0,
#       "dirty": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 12
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697592137,
#     "state": {
#       "in-package": 0.0,
#       "plain": 0.0,
#       "peanut-butter[partial]": 0.0,
#       "peanut-butter[full]": 0.0,
#       "pb+jelly[partial]": 0.0,
#       "pb+jelly[full]": 0.0,
#       "rolling": 0.0,
#       "rolled": 0.0,
#       "rolled+toothpicks[partial]": 0.0,
#       "rolled+toothpicks[full]": 0.0,
#       "ends-cut[partial]": 0.0,
#       "ends-cut[full]": 0.0,
#       "floss-underneath": 0.0,
#       "floss-crossed": 0.0,
#       "sliced[partial]": 0.0,
#       "sliced[full]": 0.0,
#       "on-plate[partial]": 1.0,
#       "on-plate[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 12
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697592137,
#     "state": {
#       "empty": 0.0,
#       "with-pinwheels[partial]": 1.0,
#       "with-pinwheels[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 12
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
#     "id": 1,
#     "last_seen": 1697592137,
#     "state": {
#       "clean": 1.0,
#       "dirty": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 12
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697592138,
#     "state": {
#       "in-package": 0.0,
#       "plain": 0.0,
#       "peanut-butter[partial]": 0.0,
#       "peanut-butter[full]": 0.0,
#       "pb+jelly[partial]": 0.0,
#       "pb+jelly[full]": 0.0,
#       "rolling": 0.0,
#       "rolled": 0.0,
#       "rolled+toothpicks[partial]": 0.0,
#       "rolled+toothpicks[full]": 0.0,
#       "ends-cut[partial]": 0.0,
#       "ends-cut[full]": 0.0,
#       "floss-underneath": 0.0,
#       "floss-crossed": 0.0,
#       "sliced[partial]": 0.0,
#       "sliced[full]": 0.0,
#       "on-plate[partial]": 1.0,
#       "on-plate[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 12
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697592138,
#     "state": {
#       "empty": 0.0,
#       "with-pinwheels[partial]": 1.0,
#       "with-pinwheels[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 12
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
#     "id": 1,
#     "last_seen": 1697592138,
#     "state": {
#       "clean": 1.0,
#       "dirty": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 12
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697592139,
#     "state": {
#       "in-package": 0.0,
#       "plain": 0.0,
#       "peanut-butter[partial]": 0.0,
#       "peanut-butter[full]": 0.0,
#       "pb+jelly[partial]": 0.0,
#       "pb+jelly[full]": 0.0,
#       "rolling": 0.0,
#       "rolled": 0.0,
#       "rolled+toothpicks[partial]": 0.0,
#       "rolled+toothpicks[full]": 0.0,
#       "ends-cut[partial]": 0.0,
#       "ends-cut[full]": 0.0,
#       "floss-underneath": 0.0,
#       "floss-crossed": 0.0,
#       "sliced[partial]": 0.0,
#       "sliced[full]": 0.0,
#       "on-plate[partial]": 1.0,
#       "on-plate[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 12
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697592139,
#     "state": {
#       "empty": 0.0,
#       "with-pinwheels[partial]": 1.0,
#       "with-pinwheels[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 12
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
#     "id": 1,
#     "last_seen": 1697592139,
#     "state": {
#       "clean": 1.0,
#       "dirty": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 12
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697592140,
#     "state": {
#       "in-package": 0.0,
#       "plain": 0.0,
#       "peanut-butter[partial]": 0.0,
#       "peanut-butter[full]": 0.0,
#       "pb+jelly[partial]": 0.0,
#       "pb+jelly[full]": 0.0,
#       "rolling": 0.0,
#       "rolled": 0.0,
#       "rolled+toothpicks[partial]": 0.0,
#       "rolled+toothpicks[full]": 0.0,
#       "ends-cut[partial]": 0.0,
#       "ends-cut[full]": 0.0,
#       "floss-underneath": 0.0,
#       "floss-crossed": 0.0,
#       "sliced[partial]": 0.0,
#       "sliced[full]": 0.0,
#       "on-plate[partial]": 0.0,
#       "on-plate[full]": 1.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 12
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697592140,
#     "state": {
#       "empty": 0.0,
#       "with-pinwheels[partial]": 0.0,
#       "with-pinwheels[full]": 1.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 12
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
#     "id": 1,
#     "last_seen": 1697592140,
#     "state": {
#       "clean": 1.0,
#       "dirty": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 12
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697592141,
#     "state": {
#       "in-package": 0.0,
#       "plain": 0.0,
#       "peanut-butter[partial]": 0.0,
#       "peanut-butter[full]": 0.0,
#       "pb+jelly[partial]": 0.0,
#       "pb+jelly[full]": 0.0,
#       "rolling": 0.0,
#       "rolled": 0.0,
#       "rolled+toothpicks[partial]": 0.0,
#       "rolled+toothpicks[full]": 0.0,
#       "ends-cut[partial]": 0.0,
#       "ends-cut[full]": 0.0,
#       "floss-underneath": 0.0,
#       "floss-crossed": 0.0,
#       "sliced[partial]": 0.0,
#       "sliced[full]": 0.0,
#       "on-plate[partial]": 0.0,
#       "on-plate[full]": 1.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 12
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697592141,
#     "state": {
#       "empty": 0.0,
#       "with-pinwheels[partial]": 0.0,
#       "with-pinwheels[full]": 1.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 12
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
#     "id": 1,
#     "last_seen": 1697592141,
#     "state": {
#       "clean": 1.0,
#       "dirty": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 12
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697592142,
#     "state": {
#       "in-package": 0.0,
#       "plain": 0.0,
#       "peanut-butter[partial]": 0.0,
#       "peanut-butter[full]": 0.0,
#       "pb+jelly[partial]": 0.0,
#       "pb+jelly[full]": 0.0,
#       "rolling": 0.0,
#       "rolled": 0.0,
#       "rolled+toothpicks[partial]": 0.0,
#       "rolled+toothpicks[full]": 0.0,
#       "ends-cut[partial]": 0.0,
#       "ends-cut[full]": 0.0,
#       "floss-underneath": 0.0,
#       "floss-crossed": 0.0,
#       "sliced[partial]": 0.0,
#       "sliced[full]": 0.0,
#       "on-plate[partial]": 0.0,
#       "on-plate[full]": 1.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 12
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697592142,
#     "state": {
#       "empty": 0.0,
#       "with-pinwheels[partial]": 0.0,
#       "with-pinwheels[full]": 1.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 12
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
#     "id": 1,
#     "last_seen": 1697592142,
#     "state": {
#       "clean": 1.0,
#       "dirty": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 12
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697592143,
#     "state": {
#       "in-package": 0.0,
#       "plain": 0.0,
#       "peanut-butter[partial]": 0.0,
#       "peanut-butter[full]": 0.0,
#       "pb+jelly[partial]": 0.0,
#       "pb+jelly[full]": 0.0,
#       "rolling": 0.0,
#       "rolled": 0.0,
#       "rolled+toothpicks[partial]": 0.0,
#       "rolled+toothpicks[full]": 0.0,
#       "ends-cut[partial]": 0.0,
#       "ends-cut[full]": 0.0,
#       "floss-underneath": 0.0,
#       "floss-crossed": 0.0,
#       "sliced[partial]": 0.0,
#       "sliced[full]": 0.0,
#       "on-plate[partial]": 0.0,
#       "on-plate[full]": 1.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 12
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697592143,
#     "state": {
#       "empty": 0.0,
#       "with-pinwheels[partial]": 0.0,
#       "with-pinwheels[full]": 1.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 12
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
#     "id": 1,
#     "last_seen": 1697592143,
#     "state": {
#       "clean": 1.0,
#       "dirty": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 12
#     }
#   }
# ]

# %%
video_id = 'oatmeal_mit-eval'
formatted_annotations_o = format_annotations(annotations, video_id)
oatmeal_annotations = read_annotated_video(formatted_annotations_o)
oatmeal_perception_outputs = make_perception_outputs(oatmeal_annotations)
save_outputs(oatmeal_perception_outputs, 'oatmeal_session')
# Out:
# [
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697591895,
#     "state": {
#       "plain": 1.0,
#       "oatmeal": 0.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697591896,
#     "state": {
#       "plain": 1.0,
#       "oatmeal": 0.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697591897,
#     "state": {
#       "plain": 1.0,
#       "oatmeal": 0.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697591898,
#     "state": {
#       "plain": 1.0,
#       "oatmeal": 0.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697591899,
#     "state": {
#       "plain": 1.0,
#       "oatmeal": 0.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697591900,
#     "state": {
#       "plain": 1.0,
#       "oatmeal": 0.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697591901,
#     "state": {
#       "plain": 1.0,
#       "oatmeal": 0.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697591902,
#     "state": {
#       "plain": 1.0,
#       "oatmeal": 0.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697591903,
#     "state": {
#       "plain": 1.0,
#       "oatmeal": 0.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697591904,
#     "state": {
#       "plain": 1.0,
#       "oatmeal": 0.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697591905,
#     "state": {
#       "plain": 1.0,
#       "oatmeal": 0.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697591906,
#     "state": {
#       "plain": 1.0,
#       "oatmeal": 0.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697591907,
#     "state": {
#       "plain": 1.0,
#       "oatmeal": 0.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697591908,
#     "state": {
#       "plain": 1.0,
#       "oatmeal": 0.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697591909,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 1.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697591910,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 1.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697591911,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 1.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697591912,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 1.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697591913,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 1.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697591914,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 1.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697591915,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 1.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697591916,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 1.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697591917,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 1.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697591918,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 1.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697591919,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 1.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697591920,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 1.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697591921,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 1.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697591922,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 1.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697591923,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 1.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697591924,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 1.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697591925,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 1.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697591926,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 1.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697591927,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 1.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697591928,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 1.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697591929,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 1.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 2
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697591930,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 1.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 2
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697591931,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 1.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 2
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697591932,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 1.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 2
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697591933,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 1.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 2
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697591934,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 1.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 2
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697591935,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 1.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 2
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697591936,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 1.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 2
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697591937,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 1.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 2
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697591938,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 1.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 2
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697591939,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 1.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 2
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697591940,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 1.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 2
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697591941,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 1.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 2
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697591942,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 1.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 2
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697591943,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 1.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 2
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697591944,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 1.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 2
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697591945,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 0.0,
#       "oatmeal+water": 1.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 2
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697591946,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 0.0,
#       "oatmeal+water": 1.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 2
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697591947,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 0.0,
#       "oatmeal+water": 1.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 2
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697591948,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 0.0,
#       "oatmeal+water": 1.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 2
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697591949,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 0.0,
#       "oatmeal+water": 1.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 2
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697591950,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 0.0,
#       "oatmeal+water": 1.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 2
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697591951,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 0.0,
#       "oatmeal+water": 1.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 3
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697591952,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 0.0,
#       "oatmeal+water": 1.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 3
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697591953,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 0.0,
#       "oatmeal+water": 1.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 3
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697591954,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 0.0,
#       "oatmeal+water": 1.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 3
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697591955,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 0.0,
#       "oatmeal+water": 1.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 3
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697591956,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 0.0,
#       "oatmeal+water": 1.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 3
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697591957,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 0.0,
#       "oatmeal+water": 1.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
# ...
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697592132,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 0.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 1.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 6
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697592133,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 0.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 1.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 6
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697592134,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 0.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 1.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 7
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697592135,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 0.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 1.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 7
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697592136,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 0.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 1.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 7
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697592137,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 0.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 1.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 7
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697592138,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 0.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 1.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 7
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697592139,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 0.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 1.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 7
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697592140,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 0.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 1.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 7
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697592141,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 0.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 1.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 7
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697592142,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 0.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 1.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 7
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697592143,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 0.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 1.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 7
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697592144,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 0.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 1.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 7
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697592145,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 0.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 1.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 7
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697592146,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 0.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 1.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 7
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697592147,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 0.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 1.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 7
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697592148,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 0.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 1.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 7
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697592149,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 0.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 1.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 7
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697592150,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 0.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 1.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 7
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697592151,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 0.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 1.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 7
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "bowl",
#     "status": "tracked",
#     "id": 3,
#     "last_seen": 1697592152,
#     "state": {
#       "plain": 0.0,
#       "oatmeal": 0.0,
#       "oatmeal+water": 0.0,
#       "oatmeal[cooked]": 0.0,
#       "oatmeal[cooked]+raisins": 0.0,
#       "oatmeal+raisins[cooked]": 0.0,
#       "oatmeal+raisins[cooked]+banana": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon": 0.0,
#       "oatmeal+raisins[cooked]+banana+cinnamon+honey": 1.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "oatmeal_mit-eval",
#       "task_id": "oatmeal",
#       "step_id": 7
#     }
#   }
# ]

# %% [markdown]
# ### Merging and Modifying Data

# %%
def simulate_state_probas(state_probas, unique_states):
    all_state_probas = {}
    
    if state_probas is None:
        state_probas = {}
    
    total_proba = 0

    for state_name, state_proba in state_probas.items():
        try:
            unique_states.remove(state_name)
        except:
            continue
        all_state_probas[state_name] = state_proba
        total_proba += state_proba

    remaining_proba = 1 - total_proba
    remaining_proba /= len(unique_states)

    for unique_state in unique_states:
        all_state_probas[unique_state] = remaining_proba
    
    return all_state_probas
        

def make_errors(annotated_video, target_step, target_object=None, target_state_probas=None):
    unique_states = copy.deepcopy(annotated_video['unique_states'][target_object])
    perception_outputs = []
    
    for step_id, step_annotations in annotated_video['records'].items():
        state_probas = None
        session_annotation = {'session_id': annotated_video['session_id'], 'task_id': annotated_video['task_id'], 'step_id': step_id}
        
        if target_step == step_id:
            state_probas = simulate_state_probas(target_state_probas, unique_states)
            
        for step_annotation in step_annotations:
            step_outputs = make_step_outputs(session_annotation, step_annotation, annotated_video['unique_states'], PERCEPTION_OUTPUT_TEMPLATE, state_probas, target_object)
            perception_outputs += step_outputs
    
    return perception_outputs


def group_by_step(session):
    session_by_step = {}
    
    for entry in session:
        step_id = entry['session']['step_id']
        if step_id not in session_by_step:
            session_by_step[step_id] = []
            
        session_by_step[step_id].append(entry)
    
    return list(session_by_step.values())


def merge_sessions(session1, session2, step_size=1):
    max_length = max(len(session1), len(session2))
    merged_sessions = []
    current_index = 0
    session1_by_step = group_by_step(session1)
    session2_by_step = group_by_step(session2)
    
    while current_index < max_length:
        selected_steps = session1_by_step[current_index: current_index+step_size]
        merged_sessions += selected_steps
        selected_steps = session2_by_step[current_index: current_index+step_size]
        merged_sessions += selected_steps
        current_index = current_index + step_size
    
    return merged_sessions

# %%
merged_sessions = merge_sessions(pinwheels_perception_outputs, oatmeal_perception_outputs, 2)
save_outputs(merged_sessions, 'merged_sessions')
# Out:
# [
#   [
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "tortilla",
#       "status": "tracked",
#       "id": 0,
#       "last_seen": 1697591895,
#       "state": {
#         "in-package": 1.0,
#         "plain": 0.0,
#         "peanut-butter[partial]": 0.0,
#         "peanut-butter[full]": 0.0,
#         "pb+jelly[partial]": 0.0,
#         "pb+jelly[full]": 0.0,
#         "rolling": 0.0,
#         "rolled": 0.0,
#         "rolled+toothpicks[partial]": 0.0,
#         "rolled+toothpicks[full]": 0.0,
#         "ends-cut[partial]": 0.0,
#         "ends-cut[full]": 0.0,
#         "floss-underneath": 0.0,
#         "floss-crossed": 0.0,
#         "sliced[partial]": 0.0,
#         "sliced[full]": 0.0,
#         "on-plate[partial]": 0.0,
#         "on-plate[full]": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 1
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "plate",
#       "status": "tracked",
#       "id": 2,
#       "last_seen": 1697591895,
#       "state": {
#         "empty": 1.0,
#         "with-pinwheels[partial]": 0.0,
#         "with-pinwheels[full]": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 1
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "knife",
#       "status": "tracked",
#       "id": 1,
#       "last_seen": 1697591895,
#       "state": {
#         "clean": 1.0,
#         "dirty": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 1
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "tortilla",
#       "status": "tracked",
#       "id": 0,
#       "last_seen": 1697591896,
#       "state": {
#         "in-package": 1.0,
#         "plain": 0.0,
#         "peanut-butter[partial]": 0.0,
#         "peanut-butter[full]": 0.0,
#         "pb+jelly[partial]": 0.0,
#         "pb+jelly[full]": 0.0,
#         "rolling": 0.0,
#         "rolled": 0.0,
#         "rolled+toothpicks[partial]": 0.0,
#         "rolled+toothpicks[full]": 0.0,
#         "ends-cut[partial]": 0.0,
#         "ends-cut[full]": 0.0,
#         "floss-underneath": 0.0,
#         "floss-crossed": 0.0,
#         "sliced[partial]": 0.0,
#         "sliced[full]": 0.0,
#         "on-plate[partial]": 0.0,
#         "on-plate[full]": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 1
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "plate",
#       "status": "tracked",
#       "id": 2,
#       "last_seen": 1697591896,
#       "state": {
#         "empty": 1.0,
#         "with-pinwheels[partial]": 0.0,
#         "with-pinwheels[full]": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 1
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "knife",
#       "status": "tracked",
#       "id": 1,
#       "last_seen": 1697591896,
#       "state": {
#         "clean": 1.0,
#         "dirty": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 1
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "tortilla",
#       "status": "tracked",
#       "id": 0,
#       "last_seen": 1697591897,
#       "state": {
#         "in-package": 1.0,
#         "plain": 0.0,
#         "peanut-butter[partial]": 0.0,
#         "peanut-butter[full]": 0.0,
#         "pb+jelly[partial]": 0.0,
#         "pb+jelly[full]": 0.0,
#         "rolling": 0.0,
#         "rolled": 0.0,
#         "rolled+toothpicks[partial]": 0.0,
#         "rolled+toothpicks[full]": 0.0,
#         "ends-cut[partial]": 0.0,
#         "ends-cut[full]": 0.0,
#         "floss-underneath": 0.0,
#         "floss-crossed": 0.0,
#         "sliced[partial]": 0.0,
#         "sliced[full]": 0.0,
#         "on-plate[partial]": 0.0,
#         "on-plate[full]": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 1
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "plate",
#       "status": "tracked",
#       "id": 2,
#       "last_seen": 1697591897,
#       "state": {
#         "empty": 1.0,
#         "with-pinwheels[partial]": 0.0,
#         "with-pinwheels[full]": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 1
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "knife",
#       "status": "tracked",
#       "id": 1,
#       "last_seen": 1697591897,
#       "state": {
#         "clean": 1.0,
#         "dirty": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 1
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "tortilla",
#       "status": "tracked",
#       "id": 0,
#       "last_seen": 1697591898,
#       "state": {
#         "in-package": 1.0,
#         "plain": 0.0,
#         "peanut-butter[partial]": 0.0,
#         "peanut-butter[full]": 0.0,
#         "pb+jelly[partial]": 0.0,
#         "pb+jelly[full]": 0.0,
#         "rolling": 0.0,
#         "rolled": 0.0,
#         "rolled+toothpicks[partial]": 0.0,
#         "rolled+toothpicks[full]": 0.0,
#         "ends-cut[partial]": 0.0,
#         "ends-cut[full]": 0.0,
#         "floss-underneath": 0.0,
#         "floss-crossed": 0.0,
#         "sliced[partial]": 0.0,
#         "sliced[full]": 0.0,
#         "on-plate[partial]": 0.0,
#         "on-plate[full]": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 1
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "plate",
#       "status": "tracked",
#       "id": 2,
#       "last_seen": 1697591898,
#       "state": {
#         "empty": 1.0,
#         "with-pinwheels[partial]": 0.0,
#         "with-pinwheels[full]": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 1
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "knife",
#       "status": "tracked",
#       "id": 1,
#       "last_seen": 1697591898,
#       "state": {
#         "clean": 1.0,
#         "dirty": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 1
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "tortilla",
#       "status": "tracked",
#       "id": 0,
#       "last_seen": 1697591899,
#       "state": {
#         "in-package": 1.0,
#         "plain": 0.0,
#         "peanut-butter[partial]": 0.0,
#         "peanut-butter[full]": 0.0,
#         "pb+jelly[partial]": 0.0,
#         "pb+jelly[full]": 0.0,
#         "rolling": 0.0,
#         "rolled": 0.0,
#         "rolled+toothpicks[partial]": 0.0,
#         "rolled+toothpicks[full]": 0.0,
#         "ends-cut[partial]": 0.0,
#         "ends-cut[full]": 0.0,
#         "floss-underneath": 0.0,
#         "floss-crossed": 0.0,
#         "sliced[partial]": 0.0,
#         "sliced[full]": 0.0,
#         "on-plate[partial]": 0.0,
#         "on-plate[full]": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 1
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "plate",
#       "status": "tracked",
#       "id": 2,
#       "last_seen": 1697591899,
#       "state": {
#         "empty": 1.0,
#         "with-pinwheels[partial]": 0.0,
#         "with-pinwheels[full]": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 1
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "knife",
#       "status": "tracked",
#       "id": 1,
#       "last_seen": 1697591899,
#       "state": {
#         "clean": 1.0,
#         "dirty": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 1
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "tortilla",
#       "status": "tracked",
#       "id": 0,
#       "last_seen": 1697591900,
#       "state": {
#         "in-package": 1.0,
#         "plain": 0.0,
#         "peanut-butter[partial]": 0.0,
#         "peanut-butter[full]": 0.0,
#         "pb+jelly[partial]": 0.0,
#         "pb+jelly[full]": 0.0,
#         "rolling": 0.0,
#         "rolled": 0.0,
#         "rolled+toothpicks[partial]": 0.0,
#         "rolled+toothpicks[full]": 0.0,
#         "ends-cut[partial]": 0.0,
#         "ends-cut[full]": 0.0,
#         "floss-underneath": 0.0,
#         "floss-crossed": 0.0,
#         "sliced[partial]": 0.0,
#         "sliced[full]": 0.0,
#         "on-plate[partial]": 0.0,
#         "on-plate[full]": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 1
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "plate",
#       "status": "tracked",
#       "id": 2,
#       "last_seen": 1697591900,
#       "state": {
#         "empty": 1.0,
#         "with-pinwheels[partial]": 0.0,
#         "with-pinwheels[full]": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 1
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "knife",
#       "status": "tracked",
#       "id": 1,
#       "last_seen": 1697591900,
#       "state": {
#         "clean": 1.0,
#         "dirty": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 1
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "tortilla",
#       "status": "tracked",
#       "id": 0,
#       "last_seen": 1697591901,
#       "state": {
#         "in-package": 0.0,
#         "plain": 1.0,
#         "peanut-butter[partial]": 0.0,
#         "peanut-butter[full]": 0.0,
#         "pb+jelly[partial]": 0.0,
#         "pb+jelly[full]": 0.0,
#         "rolling": 0.0,
#         "rolled": 0.0,
#         "rolled+toothpicks[partial]": 0.0,
#         "rolled+toothpicks[full]": 0.0,
#         "ends-cut[partial]": 0.0,
#         "ends-cut[full]": 0.0,
#         "floss-underneath": 0.0,
#         "floss-crossed": 0.0,
#         "sliced[partial]": 0.0,
#         "sliced[full]": 0.0,
#         "on-plate[partial]": 0.0,
#         "on-plate[full]": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 1
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "plate",
#       "status": "tracked",
#       "id": 2,
#       "last_seen": 1697591901,
#       "state": {
#         "empty": 1.0,
#         "with-pinwheels[partial]": 0.0,
#         "with-pinwheels[full]": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 1
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "knife",
#       "status": "tracked",
#       "id": 1,
#       "last_seen": 1697591901,
#       "state": {
#         "clean": 1.0,
#         "dirty": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 1
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "tortilla",
#       "status": "tracked",
#       "id": 0,
#       "last_seen": 1697591902,
#       "state": {
#         "in-package": 0.0,
#         "plain": 1.0,
#         "peanut-butter[partial]": 0.0,
#         "peanut-butter[full]": 0.0,
#         "pb+jelly[partial]": 0.0,
#         "pb+jelly[full]": 0.0,
#         "rolling": 0.0,
#         "rolled": 0.0,
#         "rolled+toothpicks[partial]": 0.0,
#         "rolled+toothpicks[full]": 0.0,
#         "ends-cut[partial]": 0.0,
#         "ends-cut[full]": 0.0,
#         "floss-underneath": 0.0,
#         "floss-crossed": 0.0,
#         "sliced[partial]": 0.0,
#         "sliced[full]": 0.0,
#         "on-plate[partial]": 0.0,
#         "on-plate[full]": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 1
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "plate",
#       "status": "tracked",
#       "id": 2,
#       "last_seen": 1697591902,
#       "state": {
#         "empty": 1.0,
#         "with-pinwheels[partial]": 0.0,
#         "with-pinwheels[full]": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 1
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "knife",
#       "status": "tracked",
#       "id": 1,
#       "last_seen": 1697591902,
#       "state": {
#         "clean": 1.0,
#         "dirty": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 1
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "tortilla",
#       "status": "tracked",
#       "id": 0,
#       "last_seen": 1697591903,
#       "state": {
#         "in-package": 0.0,
#         "plain": 1.0,
#         "peanut-butter[partial]": 0.0,
#         "peanut-butter[full]": 0.0,
#         "pb+jelly[partial]": 0.0,
#         "pb+jelly[full]": 0.0,
#         "rolling": 0.0,
#         "rolled": 0.0,
#         "rolled+toothpicks[partial]": 0.0,
#         "rolled+toothpicks[full]": 0.0,
#         "ends-cut[partial]": 0.0,
#         "ends-cut[full]": 0.0,
#         "floss-underneath": 0.0,
#         "floss-crossed": 0.0,
#         "sliced[partial]": 0.0,
#         "sliced[full]": 0.0,
#         "on-plate[partial]": 0.0,
#         "on-plate[full]": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 1
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "plate",
#       "status": "tracked",
#       "id": 2,
#       "last_seen": 1697591903,
#       "state": {
#         "empty": 1.0,
#         "with-pinwheels[partial]": 0.0,
#         "with-pinwheels[full]": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 1
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "knife",
#       "status": "tracked",
#       "id": 1,
#       "last_seen": 1697591903,
#       "state": {
#         "clean": 1.0,
#         "dirty": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 1
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "tortilla",
#       "status": "tracked",
#       "id": 0,
#       "last_seen": 1697591904,
#       "state": {
#         "in-package": 0.0,
#         "plain": 1.0,
#         "peanut-butter[partial]": 0.0,
#         "peanut-butter[full]": 0.0,
#         "pb+jelly[partial]": 0.0,
#         "pb+jelly[full]": 0.0,
#         "rolling": 0.0,
#         "rolled": 0.0,
#         "rolled+toothpicks[partial]": 0.0,
#         "rolled+toothpicks[full]": 0.0,
#         "ends-cut[partial]": 0.0,
#         "ends-cut[full]": 0.0,
#         "floss-underneath": 0.0,
#         "floss-crossed": 0.0,
#         "sliced[partial]": 0.0,
#         "sliced[full]": 0.0,
#         "on-plate[partial]": 0.0,
#         "on-plate[full]": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 1
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "plate",
#       "status": "tracked",
#       "id": 2,
#       "last_seen": 1697591904,
#       "state": {
#         "empty": 1.0,
#         "with-pinwheels[partial]": 0.0,
#         "with-pinwheels[full]": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 1
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "knife",
#       "status": "tracked",
#       "id": 1,
#       "last_seen": 1697591904,
#       "state": {
#         "clean": 1.0,
#         "dirty": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 1
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "tortilla",
#       "status": "tracked",
#       "id": 0,
#       "last_seen": 1697591905,
#       "state": {
#         "in-package": 0.0,
#         "plain": 1.0,
#         "peanut-butter[partial]": 0.0,
#         "peanut-butter[full]": 0.0,
#         "pb+jelly[partial]": 0.0,
#         "pb+jelly[full]": 0.0,
#         "rolling": 0.0,
#         "rolled": 0.0,
#         "rolled+toothpicks[partial]": 0.0,
#         "rolled+toothpicks[full]": 0.0,
#         "ends-cut[partial]": 0.0,
#         "ends-cut[full]": 0.0,
#         "floss-underneath": 0.0,
#         "floss-crossed": 0.0,
#         "sliced[partial]": 0.0,
#         "sliced[full]": 0.0,
#         "on-plate[partial]": 0.0,
#         "on-plate[full]": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 1
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "plate",
#       "status": "tracked",
#       "id": 2,
#       "last_seen": 1697591905,
#       "state": {
#         "empty": 1.0,
#         "with-pinwheels[partial]": 0.0,
#         "with-pinwheels[full]": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 1
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "knife",
#       "status": "tracked",
#       "id": 1,
#       "last_seen": 1697591905,
#       "state": {
#         "clean": 1.0,
#         "dirty": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 1
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "tortilla",
#       "status": "tracked",
#       "id": 0,
#       "last_seen": 1697591906,
#       "state": {
#         "in-package": 0.0,
#         "plain": 1.0,
#         "peanut-butter[partial]": 0.0,
#         "peanut-butter[full]": 0.0,
#         "pb+jelly[partial]": 0.0,
#         "pb+jelly[full]": 0.0,
#         "rolling": 0.0,
#         "rolled": 0.0,
#         "rolled+toothpicks[partial]": 0.0,
#         "rolled+toothpicks[full]": 0.0,
#         "ends-cut[partial]": 0.0,
#         "ends-cut[full]": 0.0,
#         "floss-underneath": 0.0,
#         "floss-crossed": 0.0,
#         "sliced[partial]": 0.0,
#         "sliced[full]": 0.0,
#         "on-plate[partial]": 0.0,
#         "on-plate[full]": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 1
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "plate",
#       "status": "tracked",
#       "id": 2,
#       "last_seen": 1697591906,
#       "state": {
#         "empty": 1.0,
#         "with-pinwheels[partial]": 0.0,
#         "with-pinwheels[full]": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 1
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "knife",
#       "status": "tracked",
#       "id": 1,
#       "last_seen": 1697591906,
#       "state": {
#         "clean": 1.0,
#         "dirty": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 1
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "tortilla",
#       "status": "tracked",
#       "id": 0,
#       "last_seen": 1697591907,
#       "state": {
#         "in-package": 0.0,
#         "plain": 1.0,
#         "peanut-butter[partial]": 0.0,
#         "peanut-butter[full]": 0.0,
#         "pb+jelly[partial]": 0.0,
#         "pb+jelly[full]": 0.0,
#         "rolling": 0.0,
#         "rolled": 0.0,
#         "rolled+toothpicks[partial]": 0.0,
#         "rolled+toothpicks[full]": 0.0,
#         "ends-cut[partial]": 0.0,
#         "ends-cut[full]": 0.0,
#         "floss-underneath": 0.0,
#         "floss-crossed": 0.0,
#         "sliced[partial]": 0.0,
#         "sliced[full]": 0.0,
#         "on-plate[partial]": 0.0,
#         "on-plate[full]": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 1
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "plate",
#       "status": "tracked",
#       "id": 2,
#       "last_seen": 1697591907,
#       "state": {
#         "empty": 1.0,
#         "with-pinwheels[partial]": 0.0,
#         "with-pinwheels[full]": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 1
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "knife",
#       "status": "tracked",
#       "id": 1,
#       "last_seen": 1697591907,
#       "state": {
#         "clean": 1.0,
#         "dirty": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 1
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "tortilla",
#       "status": "tracked",
#       "id": 0,
#       "last_seen": 1697591908,
#       "state": {
#         "in-package": 0.0,
#         "plain": 1.0,
#         "peanut-butter[partial]": 0.0,
#         "peanut-butter[full]": 0.0,
#         "pb+jelly[partial]": 0.0,
#         "pb+jelly[full]": 0.0,
#         "rolling": 0.0,
#         "rolled": 0.0,
#         "rolled+toothpicks[partial]": 0.0,
#         "rolled+toothpicks[full]": 0.0,
#         "ends-cut[partial]": 0.0,
#         "ends-cut[full]": 0.0,
#         "floss-underneath": 0.0,
#         "floss-crossed": 0.0,
#         "sliced[partial]": 0.0,
#         "sliced[full]": 0.0,
#         "on-plate[partial]": 0.0,
#         "on-plate[full]": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 1
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "plate",
#       "status": "tracked",
#       "id": 2,
#       "last_seen": 1697591908,
#       "state": {
#         "empty": 1.0,
#         "with-pinwheels[partial]": 0.0,
#         "with-pinwheels[full]": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 1
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "knife",
#       "status": "tracked",
#       "id": 1,
#       "last_seen": 1697591908,
#       "state": {
#         "clean": 1.0,
#         "dirty": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 1
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "tortilla",
#       "status": "tracked",
#       "id": 0,
#       "last_seen": 1697591909,
#       "state": {
#         "in-package": 0.0,
#         "plain": 1.0,
#         "peanut-butter[partial]": 0.0,
#         "peanut-butter[full]": 0.0,
#         "pb+jelly[partial]": 0.0,
#         "pb+jelly[full]": 0.0,
#         "rolling": 0.0,
#         "rolled": 0.0,
#         "rolled+toothpicks[partial]": 0.0,
#         "rolled+toothpicks[full]": 0.0,
#         "ends-cut[partial]": 0.0,
#         "ends-cut[full]": 0.0,
#         "floss-underneath": 0.0,
#         "floss-crossed": 0.0,
#         "sliced[partial]": 0.0,
#         "sliced[full]": 0.0,
#         "on-plate[partial]": 0.0,
#         "on-plate[full]": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 1
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "plate",
#       "status": "tracked",
#       "id": 2,
#       "last_seen": 1697591909,
#       "state": {
#         "empty": 1.0,
#         "with-pinwheels[partial]": 0.0,
#         "with-pinwheels[full]": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 1
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "knife",
#       "status": "tracked",
#       "id": 1,
#       "last_seen": 1697591909,
#       "state": {
#         "clean": 1.0,
#         "dirty": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 1
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "tortilla",
#       "status": "tracked",
#       "id": 0,
#       "last_seen": 1697591910,
#       "state": {
#         "in-package": 0.0,
#         "plain": 1.0,
#         "peanut-butter[partial]": 0.0,
#         "peanut-butter[full]": 0.0,
#         "pb+jelly[partial]": 0.0,
#         "pb+jelly[full]": 0.0,
#         "rolling": 0.0,
#         "rolled": 0.0,
#         "rolled+toothpicks[partial]": 0.0,
#         "rolled+toothpicks[full]": 0.0,
#         "ends-cut[partial]": 0.0,
#         "ends-cut[full]": 0.0,
#         "floss-underneath": 0.0,
#         "floss-crossed": 0.0,
#         "sliced[partial]": 0.0,
#         "sliced[full]": 0.0,
#         "on-plate[partial]": 0.0,
#         "on-plate[full]": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 1
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "plate",
#       "status": "tracked",
#       "id": 2,
#       "last_seen": 1697591910,
#       "state": {
#         "empty": 1.0,
#         "with-pinwheels[partial]": 0.0,
#         "with-pinwheels[full]": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 1
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "knife",
#       "status": "tracked",
#       "id": 1,
#       "last_seen": 1697591910,
#       "state": {
#         "clean": 1.0,
#         "dirty": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 1
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "tortilla",
#       "status": "tracked",
#       "id": 0,
#       "last_seen": 1697591911,
#       "state": {
#         "in-package": 0.0,
#         "plain": 1.0,
#         "peanut-butter[partial]": 0.0,
#         "peanut-butter[full]": 0.0,
#         "pb+jelly[partial]": 0.0,
#         "pb+jelly[full]": 0.0,
#         "rolling": 0.0,
#         "rolled": 0.0,
#         "rolled+toothpicks[partial]": 0.0,
#         "rolled+toothpicks[full]": 0.0,
#         "ends-cut[partial]": 0.0,
#         "ends-cut[full]": 0.0,
#         "floss-underneath": 0.0,
#         "floss-crossed": 0.0,
#         "sliced[partial]": 0.0,
#         "sliced[full]": 0.0,
#         "on-plate[partial]": 0.0,
#         "on-plate[full]": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 1
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "plate",
#       "status": "tracked",
#       "id": 2,
#       "last_seen": 1697591911,
#       "state": {
#         "empty": 1.0,
#         "with-pinwheels[partial]": 0.0,
#         "with-pinwheels[full]": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 1
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "knife",
#       "status": "tracked",
#       "id": 1,
#       "last_seen": 1697591911,
#       "state": {
#         "clean": 1.0,
#         "dirty": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 1
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "tortilla",
#       "status": "tracked",
#       "id": 0,
#       "last_seen": 1697591912,
#       "state": {
#         "in-package": 0.0,
#         "plain": 1.0,
#         "peanut-butter[partial]": 0.0,
#         "peanut-butter[full]": 0.0,
#         "pb+jelly[partial]": 0.0,
#         "pb+jelly[full]": 0.0,
#         "rolling": 0.0,
#         "rolled": 0.0,
#         "rolled+toothpicks[partial]": 0.0,
#         "rolled+toothpicks[full]": 0.0,
#         "ends-cut[partial]": 0.0,
#         "ends-cut[full]": 0.0,
#         "floss-underneath": 0.0,
#         "floss-crossed": 0.0,
#         "sliced[partial]": 0.0,
#         "sliced[full]": 0.0,
#         "on-plate[partial]": 0.0,
#         "on-plate[full]": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 1
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "plate",
#       "status": "tracked",
#       "id": 2,
#       "last_seen": 1697591912,
#       "state": {
#         "empty": 1.0,
#         "with-pinwheels[partial]": 0.0,
#         "with-pinwheels[full]": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 1
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "knife",
#       "status": "tracked",
#       "id": 1,
#       "last_seen": 1697591912,
#       "state": {
#         "clean": 1.0,
#         "dirty": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 1
#       }
#     }
#   ],
#   [
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "tortilla",
#       "status": "tracked",
#       "id": 0,
#       "last_seen": 1697591913,
#       "state": {
#         "in-package": 0.0,
#         "plain": 1.0,
#         "peanut-butter[partial]": 0.0,
#         "peanut-butter[full]": 0.0,
#         "pb+jelly[partial]": 0.0,
#         "pb+jelly[full]": 0.0,
#         "rolling": 0.0,
#         "rolled": 0.0,
#         "rolled+toothpicks[partial]": 0.0,
#         "rolled+toothpicks[full]": 0.0,
#         "ends-cut[partial]": 0.0,
#         "ends-cut[full]": 0.0,
#         "floss-underneath": 0.0,
#         "floss-crossed": 0.0,
#         "sliced[partial]": 0.0,
#         "sliced[full]": 0.0,
#         "on-plate[partial]": 0.0,
#         "on-plate[full]": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 2
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "plate",
#       "status": "tracked",
#       "id": 2,
#       "last_seen": 1697591913,
#       "state": {
#         "empty": 1.0,
#         "with-pinwheels[partial]": 0.0,
#         "with-pinwheels[full]": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 2
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "knife",
#       "status": "tracked",
#       "id": 1,
#       "last_seen": 1697591913,
#       "state": {
#         "clean": 1.0,
#         "dirty": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 2
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "tortilla",
#       "status": "tracked",
#       "id": 0,
#       "last_seen": 1697591914,
#       "state": {
#         "in-package": 0.0,
#         "plain": 1.0,
#         "peanut-butter[partial]": 0.0,
#         "peanut-butter[full]": 0.0,
#         "pb+jelly[partial]": 0.0,
#         "pb+jelly[full]": 0.0,
#         "rolling": 0.0,
#         "rolled": 0.0,
#         "rolled+toothpicks[partial]": 0.0,
#         "rolled+toothpicks[full]": 0.0,
#         "ends-cut[partial]": 0.0,
#         "ends-cut[full]": 0.0,
#         "floss-underneath": 0.0,
#         "floss-crossed": 0.0,
#         "sliced[partial]": 0.0,
#         "sliced[full]": 0.0,
#         "on-plate[partial]": 0.0,
#         "on-plate[full]": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 2
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "plate",
#       "status": "tracked",
#       "id": 2,
#       "last_seen": 1697591914,
#       "state": {
#         "empty": 1.0,
#         "with-pinwheels[partial]": 0.0,
#         "with-pinwheels[full]": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 2
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "knife",
#       "status": "tracked",
#       "id": 1,
#       "last_seen": 1697591914,
#       "state": {
#         "clean": 1.0,
#         "dirty": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 2
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "tortilla",
#       "status": "tracked",
#       "id": 0,
#       "last_seen": 1697591915,
#       "state": {
#         "in-package": 0.0,
#         "plain": 1.0,
#         "peanut-butter[partial]": 0.0,
#         "peanut-butter[full]": 0.0,
#         "pb+jelly[partial]": 0.0,
#         "pb+jelly[full]": 0.0,
#         "rolling": 0.0,
#         "rolled": 0.0,
#         "rolled+toothpicks[partial]": 0.0,
#         "rolled+toothpicks[full]": 0.0,
#         "ends-cut[partial]": 0.0,
#         "ends-cut[full]": 0.0,
#         "floss-underneath": 0.0,
#         "floss-crossed": 0.0,
#         "sliced[partial]": 0.0,
#         "sliced[full]": 0.0,
#         "on-plate[partial]": 0.0,
#         "on-plate[full]": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 2
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "plate",
#       "status": "tracked",
#       "id": 2,
#       "last_seen": 1697591915,
#       "state": {
#         "empty": 1.0,
#         "with-pinwheels[partial]": 0.0,
#         "with-pinwheels[full]": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 2
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "knife",
#       "status": "tracked",
#       "id": 1,
#       "last_seen": 1697591915,
#       "state": {
#         "clean": 1.0,
#         "dirty": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 2
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "tortilla",
#       "status": "tracked",
#       "id": 0,
#       "last_seen": 1697591916,
#       "state": {
#         "in-package": 0.0,
#         "plain": 1.0,
#         "peanut-butter[partial]": 0.0,
#         "peanut-butter[full]": 0.0,
#         "pb+jelly[partial]": 0.0,
#         "pb+jelly[full]": 0.0,
#         "rolling": 0.0,
#         "rolled": 0.0,
#         "rolled+toothpicks[partial]": 0.0,
#         "rolled+toothpicks[full]": 0.0,
#         "ends-cut[partial]": 0.0,
#         "ends-cut[full]": 0.0,
#         "floss-underneath": 0.0,
#         "floss-crossed": 0.0,
#         "sliced[partial]": 0.0,
#         "sliced[full]": 0.0,
#         "on-plate[partial]": 0.0,
#         "on-plate[full]": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 2
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "plate",
#       "status": "tracked",
#       "id": 2,
#       "last_seen": 1697591916,
#       "state": {
#         "empty": 1.0,
#         "with-pinwheels[partial]": 0.0,
#         "with-pinwheels[full]": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
# ...
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "knife",
#       "status": "tracked",
#       "id": 1,
#       "last_seen": 1697592136,
#       "state": {
#         "clean": 1.0,
#         "dirty": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 12
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "tortilla",
#       "status": "tracked",
#       "id": 0,
#       "last_seen": 1697592137,
#       "state": {
#         "in-package": 0.0,
#         "plain": 0.0,
#         "peanut-butter[partial]": 0.0,
#         "peanut-butter[full]": 0.0,
#         "pb+jelly[partial]": 0.0,
#         "pb+jelly[full]": 0.0,
#         "rolling": 0.0,
#         "rolled": 0.0,
#         "rolled+toothpicks[partial]": 0.0,
#         "rolled+toothpicks[full]": 0.0,
#         "ends-cut[partial]": 0.0,
#         "ends-cut[full]": 0.0,
#         "floss-underneath": 0.0,
#         "floss-crossed": 0.0,
#         "sliced[partial]": 0.0,
#         "sliced[full]": 0.0,
#         "on-plate[partial]": 1.0,
#         "on-plate[full]": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 12
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "plate",
#       "status": "tracked",
#       "id": 2,
#       "last_seen": 1697592137,
#       "state": {
#         "empty": 0.0,
#         "with-pinwheels[partial]": 1.0,
#         "with-pinwheels[full]": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 12
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "knife",
#       "status": "tracked",
#       "id": 1,
#       "last_seen": 1697592137,
#       "state": {
#         "clean": 1.0,
#         "dirty": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 12
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "tortilla",
#       "status": "tracked",
#       "id": 0,
#       "last_seen": 1697592138,
#       "state": {
#         "in-package": 0.0,
#         "plain": 0.0,
#         "peanut-butter[partial]": 0.0,
#         "peanut-butter[full]": 0.0,
#         "pb+jelly[partial]": 0.0,
#         "pb+jelly[full]": 0.0,
#         "rolling": 0.0,
#         "rolled": 0.0,
#         "rolled+toothpicks[partial]": 0.0,
#         "rolled+toothpicks[full]": 0.0,
#         "ends-cut[partial]": 0.0,
#         "ends-cut[full]": 0.0,
#         "floss-underneath": 0.0,
#         "floss-crossed": 0.0,
#         "sliced[partial]": 0.0,
#         "sliced[full]": 0.0,
#         "on-plate[partial]": 1.0,
#         "on-plate[full]": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 12
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "plate",
#       "status": "tracked",
#       "id": 2,
#       "last_seen": 1697592138,
#       "state": {
#         "empty": 0.0,
#         "with-pinwheels[partial]": 1.0,
#         "with-pinwheels[full]": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 12
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "knife",
#       "status": "tracked",
#       "id": 1,
#       "last_seen": 1697592138,
#       "state": {
#         "clean": 1.0,
#         "dirty": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 12
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "tortilla",
#       "status": "tracked",
#       "id": 0,
#       "last_seen": 1697592139,
#       "state": {
#         "in-package": 0.0,
#         "plain": 0.0,
#         "peanut-butter[partial]": 0.0,
#         "peanut-butter[full]": 0.0,
#         "pb+jelly[partial]": 0.0,
#         "pb+jelly[full]": 0.0,
#         "rolling": 0.0,
#         "rolled": 0.0,
#         "rolled+toothpicks[partial]": 0.0,
#         "rolled+toothpicks[full]": 0.0,
#         "ends-cut[partial]": 0.0,
#         "ends-cut[full]": 0.0,
#         "floss-underneath": 0.0,
#         "floss-crossed": 0.0,
#         "sliced[partial]": 0.0,
#         "sliced[full]": 0.0,
#         "on-plate[partial]": 1.0,
#         "on-plate[full]": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 12
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "plate",
#       "status": "tracked",
#       "id": 2,
#       "last_seen": 1697592139,
#       "state": {
#         "empty": 0.0,
#         "with-pinwheels[partial]": 1.0,
#         "with-pinwheels[full]": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 12
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "knife",
#       "status": "tracked",
#       "id": 1,
#       "last_seen": 1697592139,
#       "state": {
#         "clean": 1.0,
#         "dirty": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 12
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "tortilla",
#       "status": "tracked",
#       "id": 0,
#       "last_seen": 1697592140,
#       "state": {
#         "in-package": 0.0,
#         "plain": 0.0,
#         "peanut-butter[partial]": 0.0,
#         "peanut-butter[full]": 0.0,
#         "pb+jelly[partial]": 0.0,
#         "pb+jelly[full]": 0.0,
#         "rolling": 0.0,
#         "rolled": 0.0,
#         "rolled+toothpicks[partial]": 0.0,
#         "rolled+toothpicks[full]": 0.0,
#         "ends-cut[partial]": 0.0,
#         "ends-cut[full]": 0.0,
#         "floss-underneath": 0.0,
#         "floss-crossed": 0.0,
#         "sliced[partial]": 0.0,
#         "sliced[full]": 0.0,
#         "on-plate[partial]": 0.0,
#         "on-plate[full]": 1.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 12
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "plate",
#       "status": "tracked",
#       "id": 2,
#       "last_seen": 1697592140,
#       "state": {
#         "empty": 0.0,
#         "with-pinwheels[partial]": 0.0,
#         "with-pinwheels[full]": 1.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 12
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "knife",
#       "status": "tracked",
#       "id": 1,
#       "last_seen": 1697592140,
#       "state": {
#         "clean": 1.0,
#         "dirty": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 12
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "tortilla",
#       "status": "tracked",
#       "id": 0,
#       "last_seen": 1697592141,
#       "state": {
#         "in-package": 0.0,
#         "plain": 0.0,
#         "peanut-butter[partial]": 0.0,
#         "peanut-butter[full]": 0.0,
#         "pb+jelly[partial]": 0.0,
#         "pb+jelly[full]": 0.0,
#         "rolling": 0.0,
#         "rolled": 0.0,
#         "rolled+toothpicks[partial]": 0.0,
#         "rolled+toothpicks[full]": 0.0,
#         "ends-cut[partial]": 0.0,
#         "ends-cut[full]": 0.0,
#         "floss-underneath": 0.0,
#         "floss-crossed": 0.0,
#         "sliced[partial]": 0.0,
#         "sliced[full]": 0.0,
#         "on-plate[partial]": 0.0,
#         "on-plate[full]": 1.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 12
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "plate",
#       "status": "tracked",
#       "id": 2,
#       "last_seen": 1697592141,
#       "state": {
#         "empty": 0.0,
#         "with-pinwheels[partial]": 0.0,
#         "with-pinwheels[full]": 1.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 12
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "knife",
#       "status": "tracked",
#       "id": 1,
#       "last_seen": 1697592141,
#       "state": {
#         "clean": 1.0,
#         "dirty": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 12
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "tortilla",
#       "status": "tracked",
#       "id": 0,
#       "last_seen": 1697592142,
#       "state": {
#         "in-package": 0.0,
#         "plain": 0.0,
#         "peanut-butter[partial]": 0.0,
#         "peanut-butter[full]": 0.0,
#         "pb+jelly[partial]": 0.0,
#         "pb+jelly[full]": 0.0,
#         "rolling": 0.0,
#         "rolled": 0.0,
#         "rolled+toothpicks[partial]": 0.0,
#         "rolled+toothpicks[full]": 0.0,
#         "ends-cut[partial]": 0.0,
#         "ends-cut[full]": 0.0,
#         "floss-underneath": 0.0,
#         "floss-crossed": 0.0,
#         "sliced[partial]": 0.0,
#         "sliced[full]": 0.0,
#         "on-plate[partial]": 0.0,
#         "on-plate[full]": 1.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 12
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "plate",
#       "status": "tracked",
#       "id": 2,
#       "last_seen": 1697592142,
#       "state": {
#         "empty": 0.0,
#         "with-pinwheels[partial]": 0.0,
#         "with-pinwheels[full]": 1.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 12
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "knife",
#       "status": "tracked",
#       "id": 1,
#       "last_seen": 1697592142,
#       "state": {
#         "clean": 1.0,
#         "dirty": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 12
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "tortilla",
#       "status": "tracked",
#       "id": 0,
#       "last_seen": 1697592143,
#       "state": {
#         "in-package": 0.0,
#         "plain": 0.0,
#         "peanut-butter[partial]": 0.0,
#         "peanut-butter[full]": 0.0,
#         "pb+jelly[partial]": 0.0,
#         "pb+jelly[full]": 0.0,
#         "rolling": 0.0,
#         "rolled": 0.0,
#         "rolled+toothpicks[partial]": 0.0,
#         "rolled+toothpicks[full]": 0.0,
#         "ends-cut[partial]": 0.0,
#         "ends-cut[full]": 0.0,
#         "floss-underneath": 0.0,
#         "floss-crossed": 0.0,
#         "sliced[partial]": 0.0,
#         "sliced[full]": 0.0,
#         "on-plate[partial]": 0.0,
#         "on-plate[full]": 1.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 12
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "plate",
#       "status": "tracked",
#       "id": 2,
#       "last_seen": 1697592143,
#       "state": {
#         "empty": 0.0,
#         "with-pinwheels[partial]": 0.0,
#         "with-pinwheels[full]": 1.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 12
#       }
#     },
#     {
#       "pos": [
#         -0.2149151724097291,
#         -0.4343880843796524,
#         -0.6208099189217009
#       ],
#       "xyxyn": [
#         0.1,
#         0.1,
#         0.2,
#         0.2
#       ],
#       "label": "knife",
#       "status": "tracked",
#       "id": 1,
#       "last_seen": 1697592143,
#       "state": {
#         "clean": 1.0,
#         "dirty": 0.0
#       },
#       "hand_object_interaction": 0.27,
#       "session": {
#         "session_id": "pinwheels_2023.04.04-18.33.59",
#         "task_id": "pinwheels",
#         "step_id": 12
#       }
#     }
#   ]
# ]

# %%
errored_session = make_errors(pinwheels_annotations, 1, 'tortilla', {'rolled': 0.8})
save_outputs(errored_session, 'errored_session')
# Out:
# [
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697591895,
#     "state": {
#       "rolled": 0.8,
#       "in-package": 0.01176470588235294,
#       "plain": 0.01176470588235294,
#       "peanut-butter[partial]": 0.01176470588235294,
#       "peanut-butter[full]": 0.01176470588235294,
#       "pb+jelly[partial]": 0.01176470588235294,
#       "pb+jelly[full]": 0.01176470588235294,
#       "rolling": 0.01176470588235294,
#       "rolled+toothpicks[partial]": 0.01176470588235294,
#       "rolled+toothpicks[full]": 0.01176470588235294,
#       "ends-cut[partial]": 0.01176470588235294,
#       "ends-cut[full]": 0.01176470588235294,
#       "floss-underneath": 0.01176470588235294,
#       "floss-crossed": 0.01176470588235294,
#       "sliced[partial]": 0.01176470588235294,
#       "sliced[full]": 0.01176470588235294,
#       "on-plate[partial]": 0.01176470588235294,
#       "on-plate[full]": 0.01176470588235294
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697591895,
#     "state": {
#       "empty": 1.0,
#       "with-pinwheels[partial]": 0.0,
#       "with-pinwheels[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
#     "id": 1,
#     "last_seen": 1697591895,
#     "state": {
#       "clean": 1.0,
#       "dirty": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697591896,
#     "state": {
#       "rolled": 0.8,
#       "in-package": 0.01176470588235294,
#       "plain": 0.01176470588235294,
#       "peanut-butter[partial]": 0.01176470588235294,
#       "peanut-butter[full]": 0.01176470588235294,
#       "pb+jelly[partial]": 0.01176470588235294,
#       "pb+jelly[full]": 0.01176470588235294,
#       "rolling": 0.01176470588235294,
#       "rolled+toothpicks[partial]": 0.01176470588235294,
#       "rolled+toothpicks[full]": 0.01176470588235294,
#       "ends-cut[partial]": 0.01176470588235294,
#       "ends-cut[full]": 0.01176470588235294,
#       "floss-underneath": 0.01176470588235294,
#       "floss-crossed": 0.01176470588235294,
#       "sliced[partial]": 0.01176470588235294,
#       "sliced[full]": 0.01176470588235294,
#       "on-plate[partial]": 0.01176470588235294,
#       "on-plate[full]": 0.01176470588235294
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697591896,
#     "state": {
#       "empty": 1.0,
#       "with-pinwheels[partial]": 0.0,
#       "with-pinwheels[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
#     "id": 1,
#     "last_seen": 1697591896,
#     "state": {
#       "clean": 1.0,
#       "dirty": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697591897,
#     "state": {
#       "rolled": 0.8,
#       "in-package": 0.01176470588235294,
#       "plain": 0.01176470588235294,
#       "peanut-butter[partial]": 0.01176470588235294,
#       "peanut-butter[full]": 0.01176470588235294,
#       "pb+jelly[partial]": 0.01176470588235294,
#       "pb+jelly[full]": 0.01176470588235294,
#       "rolling": 0.01176470588235294,
#       "rolled+toothpicks[partial]": 0.01176470588235294,
#       "rolled+toothpicks[full]": 0.01176470588235294,
#       "ends-cut[partial]": 0.01176470588235294,
#       "ends-cut[full]": 0.01176470588235294,
#       "floss-underneath": 0.01176470588235294,
#       "floss-crossed": 0.01176470588235294,
#       "sliced[partial]": 0.01176470588235294,
#       "sliced[full]": 0.01176470588235294,
#       "on-plate[partial]": 0.01176470588235294,
#       "on-plate[full]": 0.01176470588235294
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697591897,
#     "state": {
#       "empty": 1.0,
#       "with-pinwheels[partial]": 0.0,
#       "with-pinwheels[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
#     "id": 1,
#     "last_seen": 1697591897,
#     "state": {
#       "clean": 1.0,
#       "dirty": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697591898,
#     "state": {
#       "rolled": 0.8,
#       "in-package": 0.01176470588235294,
#       "plain": 0.01176470588235294,
#       "peanut-butter[partial]": 0.01176470588235294,
#       "peanut-butter[full]": 0.01176470588235294,
#       "pb+jelly[partial]": 0.01176470588235294,
#       "pb+jelly[full]": 0.01176470588235294,
#       "rolling": 0.01176470588235294,
#       "rolled+toothpicks[partial]": 0.01176470588235294,
#       "rolled+toothpicks[full]": 0.01176470588235294,
#       "ends-cut[partial]": 0.01176470588235294,
#       "ends-cut[full]": 0.01176470588235294,
#       "floss-underneath": 0.01176470588235294,
#       "floss-crossed": 0.01176470588235294,
#       "sliced[partial]": 0.01176470588235294,
#       "sliced[full]": 0.01176470588235294,
#       "on-plate[partial]": 0.01176470588235294,
#       "on-plate[full]": 0.01176470588235294
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697591898,
#     "state": {
#       "empty": 1.0,
#       "with-pinwheels[partial]": 0.0,
#       "with-pinwheels[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
#     "id": 1,
#     "last_seen": 1697591898,
#     "state": {
#       "clean": 1.0,
#       "dirty": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697591899,
#     "state": {
#       "rolled": 0.8,
#       "in-package": 0.01176470588235294,
#       "plain": 0.01176470588235294,
#       "peanut-butter[partial]": 0.01176470588235294,
#       "peanut-butter[full]": 0.01176470588235294,
#       "pb+jelly[partial]": 0.01176470588235294,
#       "pb+jelly[full]": 0.01176470588235294,
#       "rolling": 0.01176470588235294,
#       "rolled+toothpicks[partial]": 0.01176470588235294,
#       "rolled+toothpicks[full]": 0.01176470588235294,
#       "ends-cut[partial]": 0.01176470588235294,
#       "ends-cut[full]": 0.01176470588235294,
#       "floss-underneath": 0.01176470588235294,
#       "floss-crossed": 0.01176470588235294,
#       "sliced[partial]": 0.01176470588235294,
#       "sliced[full]": 0.01176470588235294,
#       "on-plate[partial]": 0.01176470588235294,
#       "on-plate[full]": 0.01176470588235294
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697591899,
#     "state": {
#       "empty": 1.0,
#       "with-pinwheels[partial]": 0.0,
#       "with-pinwheels[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
#     "id": 1,
#     "last_seen": 1697591899,
#     "state": {
#       "clean": 1.0,
#       "dirty": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697591900,
#     "state": {
#       "rolled": 0.8,
#       "in-package": 0.01176470588235294,
#       "plain": 0.01176470588235294,
#       "peanut-butter[partial]": 0.01176470588235294,
#       "peanut-butter[full]": 0.01176470588235294,
#       "pb+jelly[partial]": 0.01176470588235294,
#       "pb+jelly[full]": 0.01176470588235294,
#       "rolling": 0.01176470588235294,
#       "rolled+toothpicks[partial]": 0.01176470588235294,
#       "rolled+toothpicks[full]": 0.01176470588235294,
#       "ends-cut[partial]": 0.01176470588235294,
#       "ends-cut[full]": 0.01176470588235294,
#       "floss-underneath": 0.01176470588235294,
#       "floss-crossed": 0.01176470588235294,
#       "sliced[partial]": 0.01176470588235294,
#       "sliced[full]": 0.01176470588235294,
#       "on-plate[partial]": 0.01176470588235294,
#       "on-plate[full]": 0.01176470588235294
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697591900,
#     "state": {
#       "empty": 1.0,
#       "with-pinwheels[partial]": 0.0,
#       "with-pinwheels[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
#     "id": 1,
#     "last_seen": 1697591900,
#     "state": {
#       "clean": 1.0,
#       "dirty": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697591901,
#     "state": {
#       "rolled": 0.8,
#       "in-package": 0.01176470588235294,
#       "plain": 0.01176470588235294,
#       "peanut-butter[partial]": 0.01176470588235294,
#       "peanut-butter[full]": 0.01176470588235294,
#       "pb+jelly[partial]": 0.01176470588235294,
#       "pb+jelly[full]": 0.01176470588235294,
#       "rolling": 0.01176470588235294,
#       "rolled+toothpicks[partial]": 0.01176470588235294,
#       "rolled+toothpicks[full]": 0.01176470588235294,
#       "ends-cut[partial]": 0.01176470588235294,
#       "ends-cut[full]": 0.01176470588235294,
#       "floss-underneath": 0.01176470588235294,
#       "floss-crossed": 0.01176470588235294,
#       "sliced[partial]": 0.01176470588235294,
#       "sliced[full]": 0.01176470588235294,
#       "on-plate[partial]": 0.01176470588235294,
#       "on-plate[full]": 0.01176470588235294
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697591901,
#     "state": {
#       "empty": 1.0,
#       "with-pinwheels[partial]": 0.0,
#       "with-pinwheels[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
#     "id": 1,
#     "last_seen": 1697591901,
#     "state": {
#       "clean": 1.0,
#       "dirty": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697591902,
#     "state": {
#       "rolled": 0.8,
#       "in-package": 0.01176470588235294,
#       "plain": 0.01176470588235294,
#       "peanut-butter[partial]": 0.01176470588235294,
#       "peanut-butter[full]": 0.01176470588235294,
#       "pb+jelly[partial]": 0.01176470588235294,
#       "pb+jelly[full]": 0.01176470588235294,
#       "rolling": 0.01176470588235294,
#       "rolled+toothpicks[partial]": 0.01176470588235294,
#       "rolled+toothpicks[full]": 0.01176470588235294,
#       "ends-cut[partial]": 0.01176470588235294,
#       "ends-cut[full]": 0.01176470588235294,
#       "floss-underneath": 0.01176470588235294,
#       "floss-crossed": 0.01176470588235294,
#       "sliced[partial]": 0.01176470588235294,
#       "sliced[full]": 0.01176470588235294,
#       "on-plate[partial]": 0.01176470588235294,
#       "on-plate[full]": 0.01176470588235294
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697591902,
#     "state": {
#       "empty": 1.0,
#       "with-pinwheels[partial]": 0.0,
#       "with-pinwheels[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
#     "id": 1,
#     "last_seen": 1697591902,
#     "state": {
#       "clean": 1.0,
#       "dirty": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697591903,
#     "state": {
#       "rolled": 0.8,
#       "in-package": 0.01176470588235294,
#       "plain": 0.01176470588235294,
#       "peanut-butter[partial]": 0.01176470588235294,
#       "peanut-butter[full]": 0.01176470588235294,
#       "pb+jelly[partial]": 0.01176470588235294,
#       "pb+jelly[full]": 0.01176470588235294,
#       "rolling": 0.01176470588235294,
#       "rolled+toothpicks[partial]": 0.01176470588235294,
#       "rolled+toothpicks[full]": 0.01176470588235294,
#       "ends-cut[partial]": 0.01176470588235294,
#       "ends-cut[full]": 0.01176470588235294,
#       "floss-underneath": 0.01176470588235294,
#       "floss-crossed": 0.01176470588235294,
#       "sliced[partial]": 0.01176470588235294,
#       "sliced[full]": 0.01176470588235294,
#       "on-plate[partial]": 0.01176470588235294,
#       "on-plate[full]": 0.01176470588235294
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697591903,
#     "state": {
#       "empty": 1.0,
#       "with-pinwheels[partial]": 0.0,
#       "with-pinwheels[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
#     "id": 1,
#     "last_seen": 1697591903,
#     "state": {
#       "clean": 1.0,
#       "dirty": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697591904,
#     "state": {
#       "rolled": 0.8,
#       "in-package": 0.01176470588235294,
#       "plain": 0.01176470588235294,
#       "peanut-butter[partial]": 0.01176470588235294,
#       "peanut-butter[full]": 0.01176470588235294,
#       "pb+jelly[partial]": 0.01176470588235294,
#       "pb+jelly[full]": 0.01176470588235294,
#       "rolling": 0.01176470588235294,
#       "rolled+toothpicks[partial]": 0.01176470588235294,
#       "rolled+toothpicks[full]": 0.01176470588235294,
#       "ends-cut[partial]": 0.01176470588235294,
#       "ends-cut[full]": 0.01176470588235294,
#       "floss-underneath": 0.01176470588235294,
#       "floss-crossed": 0.01176470588235294,
#       "sliced[partial]": 0.01176470588235294,
#       "sliced[full]": 0.01176470588235294,
#       "on-plate[partial]": 0.01176470588235294,
#       "on-plate[full]": 0.01176470588235294
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697591904,
#     "state": {
#       "empty": 1.0,
#       "with-pinwheels[partial]": 0.0,
#       "with-pinwheels[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
#     "id": 1,
#     "last_seen": 1697591904,
#     "state": {
#       "clean": 1.0,
#       "dirty": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697591905,
#     "state": {
#       "rolled": 0.8,
#       "in-package": 0.01176470588235294,
#       "plain": 0.01176470588235294,
#       "peanut-butter[partial]": 0.01176470588235294,
#       "peanut-butter[full]": 0.01176470588235294,
#       "pb+jelly[partial]": 0.01176470588235294,
#       "pb+jelly[full]": 0.01176470588235294,
#       "rolling": 0.01176470588235294,
#       "rolled+toothpicks[partial]": 0.01176470588235294,
#       "rolled+toothpicks[full]": 0.01176470588235294,
#       "ends-cut[partial]": 0.01176470588235294,
#       "ends-cut[full]": 0.01176470588235294,
#       "floss-underneath": 0.01176470588235294,
#       "floss-crossed": 0.01176470588235294,
#       "sliced[partial]": 0.01176470588235294,
#       "sliced[full]": 0.01176470588235294,
#       "on-plate[partial]": 0.01176470588235294,
#       "on-plate[full]": 0.01176470588235294
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697591905,
#     "state": {
#       "empty": 1.0,
#       "with-pinwheels[partial]": 0.0,
#       "with-pinwheels[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
#     "id": 1,
#     "last_seen": 1697591905,
#     "state": {
#       "clean": 1.0,
#       "dirty": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697591906,
#     "state": {
#       "rolled": 0.8,
#       "in-package": 0.01176470588235294,
#       "plain": 0.01176470588235294,
#       "peanut-butter[partial]": 0.01176470588235294,
#       "peanut-butter[full]": 0.01176470588235294,
#       "pb+jelly[partial]": 0.01176470588235294,
#       "pb+jelly[full]": 0.01176470588235294,
#       "rolling": 0.01176470588235294,
#       "rolled+toothpicks[partial]": 0.01176470588235294,
#       "rolled+toothpicks[full]": 0.01176470588235294,
#       "ends-cut[partial]": 0.01176470588235294,
#       "ends-cut[full]": 0.01176470588235294,
#       "floss-underneath": 0.01176470588235294,
#       "floss-crossed": 0.01176470588235294,
#       "sliced[partial]": 0.01176470588235294,
#       "sliced[full]": 0.01176470588235294,
#       "on-plate[partial]": 0.01176470588235294,
#       "on-plate[full]": 0.01176470588235294
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697591906,
#     "state": {
#       "empty": 1.0,
#       "with-pinwheels[partial]": 0.0,
#       "with-pinwheels[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
#     "id": 1,
#     "last_seen": 1697591906,
#     "state": {
#       "clean": 1.0,
#       "dirty": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697591907,
#     "state": {
#       "rolled": 0.8,
#       "in-package": 0.01176470588235294,
#       "plain": 0.01176470588235294,
#       "peanut-butter[partial]": 0.01176470588235294,
#       "peanut-butter[full]": 0.01176470588235294,
#       "pb+jelly[partial]": 0.01176470588235294,
#       "pb+jelly[full]": 0.01176470588235294,
#       "rolling": 0.01176470588235294,
#       "rolled+toothpicks[partial]": 0.01176470588235294,
#       "rolled+toothpicks[full]": 0.01176470588235294,
#       "ends-cut[partial]": 0.01176470588235294,
#       "ends-cut[full]": 0.01176470588235294,
#       "floss-underneath": 0.01176470588235294,
#       "floss-crossed": 0.01176470588235294,
#       "sliced[partial]": 0.01176470588235294,
#       "sliced[full]": 0.01176470588235294,
#       "on-plate[partial]": 0.01176470588235294,
#       "on-plate[full]": 0.01176470588235294
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697591907,
#     "state": {
#       "empty": 1.0,
#       "with-pinwheels[partial]": 0.0,
#       "with-pinwheels[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
#     "id": 1,
#     "last_seen": 1697591907,
#     "state": {
#       "clean": 1.0,
#       "dirty": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697591908,
#     "state": {
#       "rolled": 0.8,
#       "in-package": 0.01176470588235294,
#       "plain": 0.01176470588235294,
#       "peanut-butter[partial]": 0.01176470588235294,
#       "peanut-butter[full]": 0.01176470588235294,
#       "pb+jelly[partial]": 0.01176470588235294,
#       "pb+jelly[full]": 0.01176470588235294,
#       "rolling": 0.01176470588235294,
#       "rolled+toothpicks[partial]": 0.01176470588235294,
#       "rolled+toothpicks[full]": 0.01176470588235294,
#       "ends-cut[partial]": 0.01176470588235294,
#       "ends-cut[full]": 0.01176470588235294,
#       "floss-underneath": 0.01176470588235294,
#       "floss-crossed": 0.01176470588235294,
#       "sliced[partial]": 0.01176470588235294,
#       "sliced[full]": 0.01176470588235294,
#       "on-plate[partial]": 0.01176470588235294,
#       "on-plate[full]": 0.01176470588235294
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697591908,
#     "state": {
#       "empty": 1.0,
#       "with-pinwheels[partial]": 0.0,
#       "with-pinwheels[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
#     "id": 1,
#     "last_seen": 1697591908,
#     "state": {
#       "clean": 1.0,
#       "dirty": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697591909,
#     "state": {
#       "rolled": 0.8,
#       "in-package": 0.01176470588235294,
#       "plain": 0.01176470588235294,
#       "peanut-butter[partial]": 0.01176470588235294,
#       "peanut-butter[full]": 0.01176470588235294,
#       "pb+jelly[partial]": 0.01176470588235294,
#       "pb+jelly[full]": 0.01176470588235294,
#       "rolling": 0.01176470588235294,
#       "rolled+toothpicks[partial]": 0.01176470588235294,
#       "rolled+toothpicks[full]": 0.01176470588235294,
#       "ends-cut[partial]": 0.01176470588235294,
#       "ends-cut[full]": 0.01176470588235294,
#       "floss-underneath": 0.01176470588235294,
#       "floss-crossed": 0.01176470588235294,
#       "sliced[partial]": 0.01176470588235294,
#       "sliced[full]": 0.01176470588235294,
#       "on-plate[partial]": 0.01176470588235294,
#       "on-plate[full]": 0.01176470588235294
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697591909,
#     "state": {
#       "empty": 1.0,
#       "with-pinwheels[partial]": 0.0,
#       "with-pinwheels[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
#     "id": 1,
#     "last_seen": 1697591909,
#     "state": {
#       "clean": 1.0,
#       "dirty": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697591910,
#     "state": {
#       "rolled": 0.8,
#       "in-package": 0.01176470588235294,
#       "plain": 0.01176470588235294,
#       "peanut-butter[partial]": 0.01176470588235294,
#       "peanut-butter[full]": 0.01176470588235294,
#       "pb+jelly[partial]": 0.01176470588235294,
#       "pb+jelly[full]": 0.01176470588235294,
#       "rolling": 0.01176470588235294,
#       "rolled+toothpicks[partial]": 0.01176470588235294,
#       "rolled+toothpicks[full]": 0.01176470588235294,
#       "ends-cut[partial]": 0.01176470588235294,
#       "ends-cut[full]": 0.01176470588235294,
#       "floss-underneath": 0.01176470588235294,
#       "floss-crossed": 0.01176470588235294,
#       "sliced[partial]": 0.01176470588235294,
#       "sliced[full]": 0.01176470588235294,
#       "on-plate[partial]": 0.01176470588235294,
#       "on-plate[full]": 0.01176470588235294
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697591910,
#     "state": {
#       "empty": 1.0,
#       "with-pinwheels[partial]": 0.0,
#       "with-pinwheels[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
#     "id": 1,
#     "last_seen": 1697591910,
#     "state": {
#       "clean": 1.0,
#       "dirty": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697591911,
#     "state": {
#       "rolled": 0.8,
#       "in-package": 0.01176470588235294,
#       "plain": 0.01176470588235294,
#       "peanut-butter[partial]": 0.01176470588235294,
#       "peanut-butter[full]": 0.01176470588235294,
#       "pb+jelly[partial]": 0.01176470588235294,
#       "pb+jelly[full]": 0.01176470588235294,
#       "rolling": 0.01176470588235294,
#       "rolled+toothpicks[partial]": 0.01176470588235294,
#       "rolled+toothpicks[full]": 0.01176470588235294,
#       "ends-cut[partial]": 0.01176470588235294,
#       "ends-cut[full]": 0.01176470588235294,
#       "floss-underneath": 0.01176470588235294,
#       "floss-crossed": 0.01176470588235294,
#       "sliced[partial]": 0.01176470588235294,
#       "sliced[full]": 0.01176470588235294,
#       "on-plate[partial]": 0.01176470588235294,
#       "on-plate[full]": 0.01176470588235294
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697591911,
#     "state": {
#       "empty": 1.0,
#       "with-pinwheels[partial]": 0.0,
#       "with-pinwheels[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
#     "id": 1,
#     "last_seen": 1697591911,
#     "state": {
#       "clean": 1.0,
#       "dirty": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697591912,
#     "state": {
#       "rolled": 0.8,
#       "in-package": 0.01176470588235294,
#       "plain": 0.01176470588235294,
#       "peanut-butter[partial]": 0.01176470588235294,
#       "peanut-butter[full]": 0.01176470588235294,
#       "pb+jelly[partial]": 0.01176470588235294,
#       "pb+jelly[full]": 0.01176470588235294,
#       "rolling": 0.01176470588235294,
#       "rolled+toothpicks[partial]": 0.01176470588235294,
#       "rolled+toothpicks[full]": 0.01176470588235294,
#       "ends-cut[partial]": 0.01176470588235294,
#       "ends-cut[full]": 0.01176470588235294,
#       "floss-underneath": 0.01176470588235294,
#       "floss-crossed": 0.01176470588235294,
#       "sliced[partial]": 0.01176470588235294,
#       "sliced[full]": 0.01176470588235294,
#       "on-plate[partial]": 0.01176470588235294,
#       "on-plate[full]": 0.01176470588235294
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697591912,
#     "state": {
#       "empty": 1.0,
#       "with-pinwheels[partial]": 0.0,
#       "with-pinwheels[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
#     "id": 1,
#     "last_seen": 1697591912,
#     "state": {
#       "clean": 1.0,
#       "dirty": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 1
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697591913,
#     "state": null,
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 2
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697591913,
#     "state": {
#       "empty": 1.0,
#       "with-pinwheels[partial]": 0.0,
#       "with-pinwheels[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 2
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
#     "id": 1,
#     "last_seen": 1697591913,
#     "state": {
#       "clean": 1.0,
#       "dirty": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 2
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697591914,
#     "state": null,
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 2
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697591914,
#     "state": {
#       "empty": 1.0,
#       "with-pinwheels[partial]": 0.0,
#       "with-pinwheels[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 2
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
#     "id": 1,
#     "last_seen": 1697591914,
#     "state": {
#       "clean": 1.0,
#       "dirty": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 2
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697591915,
#     "state": null,
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 2
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697591915,
#     "state": {
#       "empty": 1.0,
#       "with-pinwheels[partial]": 0.0,
#       "with-pinwheels[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 2
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
#     "id": 1,
#     "last_seen": 1697591915,
#     "state": {
#       "clean": 1.0,
#       "dirty": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 2
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697591916,
#     "state": null,
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 2
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697591916,
#     "state": {
#       "empty": 1.0,
#       "with-pinwheels[partial]": 0.0,
#       "with-pinwheels[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 2
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
#     "id": 1,
#     "last_seen": 1697591916,
#     "state": {
#       "clean": 1.0,
#       "dirty": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 2
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697591917,
#     "state": null,
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 2
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697591917,
#     "state": {
#       "empty": 1.0,
#       "with-pinwheels[partial]": 0.0,
#       "with-pinwheels[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 2
#     }
#   },
#   {
#     "pos": [
# ...
#     "last_seen": 1697592133,
#     "state": null,
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 11
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697592133,
#     "state": {
#       "empty": 1.0,
#       "with-pinwheels[partial]": 0.0,
#       "with-pinwheels[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 11
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
#     "id": 1,
#     "last_seen": 1697592133,
#     "state": {
#       "clean": 1.0,
#       "dirty": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 11
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697592134,
#     "state": null,
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 12
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697592134,
#     "state": {
#       "empty": 1.0,
#       "with-pinwheels[partial]": 0.0,
#       "with-pinwheels[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 12
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
#     "id": 1,
#     "last_seen": 1697592134,
#     "state": {
#       "clean": 1.0,
#       "dirty": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 12
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697592135,
#     "state": null,
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 12
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697592135,
#     "state": {
#       "empty": 0.0,
#       "with-pinwheels[partial]": 1.0,
#       "with-pinwheels[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 12
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
#     "id": 1,
#     "last_seen": 1697592135,
#     "state": {
#       "clean": 1.0,
#       "dirty": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 12
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697592136,
#     "state": null,
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 12
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697592136,
#     "state": {
#       "empty": 0.0,
#       "with-pinwheels[partial]": 1.0,
#       "with-pinwheels[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 12
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
#     "id": 1,
#     "last_seen": 1697592136,
#     "state": {
#       "clean": 1.0,
#       "dirty": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 12
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697592137,
#     "state": null,
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 12
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697592137,
#     "state": {
#       "empty": 0.0,
#       "with-pinwheels[partial]": 1.0,
#       "with-pinwheels[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 12
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
#     "id": 1,
#     "last_seen": 1697592137,
#     "state": {
#       "clean": 1.0,
#       "dirty": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 12
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697592138,
#     "state": null,
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 12
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697592138,
#     "state": {
#       "empty": 0.0,
#       "with-pinwheels[partial]": 1.0,
#       "with-pinwheels[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 12
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
#     "id": 1,
#     "last_seen": 1697592138,
#     "state": {
#       "clean": 1.0,
#       "dirty": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 12
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697592139,
#     "state": null,
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 12
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697592139,
#     "state": {
#       "empty": 0.0,
#       "with-pinwheels[partial]": 1.0,
#       "with-pinwheels[full]": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 12
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
#     "id": 1,
#     "last_seen": 1697592139,
#     "state": {
#       "clean": 1.0,
#       "dirty": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 12
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697592140,
#     "state": null,
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 12
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697592140,
#     "state": {
#       "empty": 0.0,
#       "with-pinwheels[partial]": 0.0,
#       "with-pinwheels[full]": 1.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 12
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
#     "id": 1,
#     "last_seen": 1697592140,
#     "state": {
#       "clean": 1.0,
#       "dirty": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 12
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697592141,
#     "state": null,
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 12
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697592141,
#     "state": {
#       "empty": 0.0,
#       "with-pinwheels[partial]": 0.0,
#       "with-pinwheels[full]": 1.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 12
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
#     "id": 1,
#     "last_seen": 1697592141,
#     "state": {
#       "clean": 1.0,
#       "dirty": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 12
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697592142,
#     "state": null,
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 12
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697592142,
#     "state": {
#       "empty": 0.0,
#       "with-pinwheels[partial]": 0.0,
#       "with-pinwheels[full]": 1.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 12
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
#     "id": 1,
#     "last_seen": 1697592142,
#     "state": {
#       "clean": 1.0,
#       "dirty": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 12
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "tortilla",
#     "status": "tracked",
#     "id": 0,
#     "last_seen": 1697592143,
#     "state": null,
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 12
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "plate",
#     "status": "tracked",
#     "id": 2,
#     "last_seen": 1697592143,
#     "state": {
#       "empty": 0.0,
#       "with-pinwheels[partial]": 0.0,
#       "with-pinwheels[full]": 1.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 12
#     }
#   },
#   {
#     "pos": [
#       -0.2149151724097291,
#       -0.4343880843796524,
#       -0.6208099189217009
#     ],
#     "xyxyn": [
#       0.1,
#       0.1,
#       0.2,
#       0.2
#     ],
#     "label": "knife",
#     "status": "tracked",
#     "id": 1,
#     "last_seen": 1697592143,
#     "state": {
#       "clean": 1.0,
#       "dirty": 0.0
#     },
#     "hand_object_interaction": 0.27,
#     "session": {
#       "session_id": "pinwheels_2023.04.04-18.33.59",
#       "task_id": "pinwheels",
#       "step_id": 12
#     }
#   }
# ]
